# %%
import json
import pandas as pd

# %%
ruta1 = 'datos_entrada/horarios_20211_Facultad_artes_transformado.json'
ruta2 = 'datos_entrada/horarios_20211_Facultad_tecnologica_transformado.json'
ruta3 = 'datos_entrada/horarios_20211_Facultad_ciencias_transformado.json'
ruta4 = 'datos_entrada/horarios_20211_Facultad_ingenieria_transformado.json'
ruta5 = 'datos_entrada/horarios_20211_Facultad_medio_ambiente_transformado.json'
ruta6 = 'datos_entrada/horarios_20211_segunda_lengua_transformado.json'

# %%
df =  pd.read_json (r'datos_entrada/horarios_20211_Facultad_tecnologica_transformado.json')

# %%
df.head(5)
# Out:
#    Cod        Dia                       Docente  Edificio  \
# 0    3      LUNES  ACOSTA CASTILLO JOHN GABRIEL  BLOQUE 9
# 1    3      LUNES  ACOSTA CASTILLO JOHN GABRIEL  BLOQUE 9
# 2    3     MARTES  ACOSTA CASTILLO JOHN GABRIEL  BLOQUE 9
# 3    3     MARTES  ACOSTA CASTILLO JOHN GABRIEL  BLOQUE 9
# 4    3  MIERCOLES  ACOSTA CASTILLO JOHN GABRIEL  BLOQUE 5
#
#                Espacio_Academico      Grp   Hora  INSCRITOS  \
# 0  FISICA I: MECANICA NEWTONIANA  779-208  16-17         30
# 1  FISICA I: MECANICA NEWTONIANA  779-208  17-18         30
# 2  FISICA I: MECANICA NEWTONIANA  779-208  16-17         30
# 3  FISICA I: MECANICA NEWTONIANA  779-208  17-18         30
# 4  FISICA I: MECANICA NEWTONIANA  779-208  12-13         30
#
#                         Proyecto_curricular                  Salon  \
# 0  CONV. SED - TECNOLOGIA CONSTRUC. CIVILES               AULA 202
# 1  CONV. SED - TECNOLOGIA CONSTRUC. CIVILES               AULA 202
# ...

# %%
df[df.Espacio_Academico.str.contains('\?\?')]
# Out:
#         Cod        Dia                       Docente            Edificio  \
# 3171  11601  MIERCOLES           ALBA PULIDO RODRIGO  BLOQUE 1, 2, 3 Y 4
# 3172  11601  MIERCOLES           ALBA PULIDO RODRIGO  BLOQUE 1, 2, 3 Y 4
# 3173  11601    VIERNES           ALBA PULIDO RODRIGO  BLOQUE 1, 2, 3 Y 4
# 3174  11601    VIERNES           ALBA PULIDO RODRIGO  BLOQUE 1, 2, 3 Y 4
# 3175  11601     SABADO        CHACON CEPEDA NORBERTO        BLOQUE 11-12
# 3176  11601     SABADO        CHACON CEPEDA NORBERTO        BLOQUE 11-12
# 3177  11601     SABADO        CHACON CEPEDA NORBERTO        BLOQUE 11-12
# 3178  11601     SABADO        CHACON CEPEDA NORBERTO        BLOQUE 11-12
# 3179  11601     MARTES           ALBA PULIDO RODRIGO  BLOQUE 1, 2, 3 Y 4
# 3180  11601     MARTES           ALBA PULIDO RODRIGO  BLOQUE 1, 2, 3 Y 4
# 3181  11601     JUEVES           ALBA PULIDO RODRIGO  BLOQUE 1, 2, 3 Y 4
# 3182  11601     JUEVES           ALBA PULIDO RODRIGO  BLOQUE 1, 2, 3 Y 4
# ...

# %%
dictionary = {'\?\?':'@@'}
df.replace(dictionary, regex=True, inplace=True)
df[df.Espacio_Academico.str.contains('\@\@')]
# Out:
#         Cod        Dia                       Docente            Edificio  \
# 3171  11601  MIERCOLES           ALBA PULIDO RODRIGO  BLOQUE 1, 2, 3 Y 4
# 3172  11601  MIERCOLES           ALBA PULIDO RODRIGO  BLOQUE 1, 2, 3 Y 4
# 3173  11601    VIERNES           ALBA PULIDO RODRIGO  BLOQUE 1, 2, 3 Y 4
# 3174  11601    VIERNES           ALBA PULIDO RODRIGO  BLOQUE 1, 2, 3 Y 4
# 3175  11601     SABADO        CHACON CEPEDA NORBERTO        BLOQUE 11-12
# 3176  11601     SABADO        CHACON CEPEDA NORBERTO        BLOQUE 11-12
# 3177  11601     SABADO        CHACON CEPEDA NORBERTO        BLOQUE 11-12
# 3178  11601     SABADO        CHACON CEPEDA NORBERTO        BLOQUE 11-12
# 3179  11601     MARTES           ALBA PULIDO RODRIGO  BLOQUE 1, 2, 3 Y 4
# 3180  11601     MARTES           ALBA PULIDO RODRIGO  BLOQUE 1, 2, 3 Y 4
# 3181  11601     JUEVES           ALBA PULIDO RODRIGO  BLOQUE 1, 2, 3 Y 4
# 3182  11601     JUEVES           ALBA PULIDO RODRIGO  BLOQUE 1, 2, 3 Y 4
# ...

# %%
dictionary = {'COSTOS DE PRODUCCI@@N':'COSTOS DE PRODUCCION', 'INTRODUCCI@@N A LA ELECTRICIDAD': 'INTRODUCCION A LA ELECTRICIDAD'}
df.replace(dictionary, regex=True, inplace=True)
df[df.Espacio_Academico.str.contains('\@\@')]
# Out:
# Empty DataFrame
# Columns: [Cod, Dia, Docente, Edificio, Espacio_Academico, Grp, Hora, INSCRITOS, Proyecto_curricular, Salon, Sede]
# Index: []

# %%
df[df.Espacio_Academico.str.contains('\?')]
# Out:
#         Cod        Dia                          Docente            Edificio  \
# 132   19406      LUNES          PACHECO GARCIA ROBINSON            BLOQUE 9
# 133   19406      LUNES          PACHECO GARCIA ROBINSON            BLOQUE 9
# 134   19406  MIERCOLES          PACHECO GARCIA ROBINSON  BLOQUE 1, 2, 3 Y 4
# 135   19406  MIERCOLES          PACHECO GARCIA ROBINSON  BLOQUE 1, 2, 3 Y 4
# 256    7104      LUNES       PINEDA JAIMES JORGE ARTURO            BLOQUE 9
# ...     ...        ...                              ...                 ...
# 4437   1526     MARTES  CASTANG MONTIEL GERARDO ALBERTO  BLOQUE 1, 2, 3 Y 4
# 4438   1526      LUNES       LOPEZ OSORIO LEYDI YOLANDA            BLOQUE 5
# 4439   1526      LUNES       LOPEZ OSORIO LEYDI YOLANDA            BLOQUE 5
# 4440   1526  MIERCOLES       LOPEZ OSORIO LEYDI YOLANDA  BLOQUE 1, 2, 3 Y 4
# 4441   1526  MIERCOLES       LOPEZ OSORIO LEYDI YOLANDA  BLOQUE 1, 2, 3 Y 4
#
# ...

# %%
dictionary = {'\?':'Ñ'}
df.replace(dictionary, regex=True, inplace=True)
df[df.Docente.str.contains('Ñ')]
# Out:
#        Cod     Dia                       Docente            Edificio  \
# 12      88  JUEVES   RIAÑO PULIDO ANDRES JHOVANY  BLOQUE 1, 2, 3 Y 4
# 13      88  JUEVES   RIAÑO PULIDO ANDRES JHOVANY  BLOQUE 1, 2, 3 Y 4
# 14      88  JUEVES   RIAÑO PULIDO ANDRES JHOVANY  BLOQUE 1, 2, 3 Y 4
# 15      88  JUEVES   RIAÑO PULIDO ANDRES JHOVANY  BLOQUE 1, 2, 3 Y 4
# 16      88  SABADO   RIAÑO PULIDO ANDRES JHOVANY            BLOQUE 9
# ...    ...     ...                           ...                 ...
# 5273  1213  JUEVES  TELLO CASTAÑEDA MARTHA LUCIA  BLOQUE 1, 2, 3 Y 4
# 5274  1213  MARTES  TELLO CASTAÑEDA MARTHA LUCIA  BLOQUE 1, 2, 3 Y 4
# 5275  1213  MARTES  TELLO CASTAÑEDA MARTHA LUCIA  BLOQUE 1, 2, 3 Y 4
# 5276  1213  JUEVES  TELLO CASTAÑEDA MARTHA LUCIA  BLOQUE 1, 2, 3 Y 4
# 5277  1213  JUEVES  TELLO CASTAÑEDA MARTHA LUCIA  BLOQUE 1, 2, 3 Y 4
#
#              Espacio_Academico      Grp   Hora  INSCRITOS  \
# 12    ECUACIONES DIFERENCIALES  779-208  14-15         22
# ...

# %%
df[df.Espacio_Academico.str.contains('Ñ')]
# Out:
#         Cod        Dia                          Docente            Edificio  \
# 132   19406      LUNES          PACHECO GARCIA ROBINSON            BLOQUE 9
# 133   19406      LUNES          PACHECO GARCIA ROBINSON            BLOQUE 9
# 134   19406  MIERCOLES          PACHECO GARCIA ROBINSON  BLOQUE 1, 2, 3 Y 4
# 135   19406  MIERCOLES          PACHECO GARCIA ROBINSON  BLOQUE 1, 2, 3 Y 4
# 256    7104      LUNES       PINEDA JAIMES JORGE ARTURO            BLOQUE 9
# ...     ...        ...                              ...                 ...
# 4437   1526     MARTES  CASTANG MONTIEL GERARDO ALBERTO  BLOQUE 1, 2, 3 Y 4
# 4438   1526      LUNES       LOPEZ OSORIO LEYDI YOLANDA            BLOQUE 5
# 4439   1526      LUNES       LOPEZ OSORIO LEYDI YOLANDA            BLOQUE 5
# 4440   1526  MIERCOLES       LOPEZ OSORIO LEYDI YOLANDA  BLOQUE 1, 2, 3 Y 4
# 4441   1526  MIERCOLES       LOPEZ OSORIO LEYDI YOLANDA  BLOQUE 1, 2, 3 Y 4
#
# ...

# %%
df.to_json(r'horarios_20211_Facultad_tecnologica_limpio.json',orient='records')
