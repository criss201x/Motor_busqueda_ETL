# %%
import pdfplumber
import re

# %%
proyecto_curricular = ""
espacio_Academico = ""
dia = ""
hora = ""
sede = ""
edificio = ""
salon = ""
docente = ""
grp = ""
inscritos = 0
cod = 0
json_constructor = []

with pdfplumber.open('horarios_20211_Facultad_Artes.pdf') as pdf:        x
    #pagina = pdf.pages[23]
    i = 0
    for pagina in pdf.pages:
        text = pagina.extract_text()
        if text is not None:
            for linea in text.split('\n'):                
                
                if re.search('PROYECTO CURRICULAR', linea): proyecto_curricular = re.search('PROYECTO CURRICULAR (.*)', linea)
                if re.search('GRP.', linea): grp = re.search('GRP\. (.*)', linea)
                if re.search('INSCRITOS', linea): inscritos = re.search('INSCRITOS (.*)', linea)
                if re.search('ESPACIO ACADEMICO', linea): espacio_Academico = re.search('ESPACIO ACADEMICO (.*)', linea)   
 
                if re.search('^[0-9]', linea) is not None:            
                    linea = re.sub("\s\s+", " ", linea) 
                    cod = re.search('^[0-9]*', linea)                
                    hora = re.search('.[0-9]\-[0-9].', linea)
                    dia = re.search('^[0-9]+ (.*) (LUNES|MARTES|MIERCOLES|JUEVES|VIERNES|SABADO|DOMINGO)', linea)

                    sede = re.search(' (ACADEMIA|CENTRO|POR ASIGNAR|SOTANOS|) ', linea)
                    sede = 'ACADEMIA SUPERIOR ARTES-ASAB' if sede.group(1) == 'ACADEMIA' else sede.group(1)
                    sede = 'CENTRO CULTURAL NUEVA SANTAFE' if sede == 'CENTRO' else sede
                    sede = 'SOTANOS AVENIDA JIMENEZ' if sede == 'SOTANOS' else sede

                    edificio = re.search(' (ACADEMIA|CENTRO|POR ASIGNAR|SOTANOS|) (PALACIO LA MERCED|CENTRO CULTURAL NUEVA|POR ASIGNAR|SOTANOS) ', linea)
                    edificio = 'CENTRO CULTURAL NUEVA SANTAFE' if edificio.group(2) == 'CENTRO CULTURAL NUEVA' else edificio.group(2)

                    salon = re.search(' (ACADEMIA|CENTRO|POR ASIGNAR|SOTANOS) (PALACIO LA MERCED|CENTRO CULTURAL NUEVA|POR ASIGNAR|SOTANOS) (AUDITORIO PRINCIPAL|AUDITORIO SAMUEL BEDOYA|BIBLIOTECA|CENTRO DE PRODUCCION|HORNOS|LABORATORIO DE|PERCUSION ENSAMBLE|POR ASIGNAR|S\. PIEDRA A|S\.BIBLIOTEC|SALA DE EXPOSICIONES D 230|SALON DE INFORMATICA A 103|SALON \w [0-9]* \- SALA DIGITAL|SALON [0-9]* A \- PROYECTOS DE|SALON [0-9]* B \- CONSERJERIA|SALON \w [0-9]*|SALON J\-[0-9] \w|SALON \w\-[0-9]*|SALON DE PIANO [0-9]+|SALON DE PERCUSION|SALON DE MUSICA \w [0-9]+|SALON DEL RINCON|SALON MULTIPLE|SALON MUSICA [0-9]*|SALON [0-9]*|S\. [A-Z]+|TALLER DE CERAMICA B016|TALLER DE IMAGEN ESCENICA|TALLER [A-Z]+ [A-Z]+|TEATRINO SALON A 125|VITRALES A010)', linea)
                    salon = 'CENTRO DE PRODUCCION AUDIOVISUAL' if salon.group(3) == 'CENTRO DE PRODUCCION' else salon.group(3)
                    salon = 'LABORATORIO DE FOTOGRAFIA' if salon == 'LABORATORIO DE' else salon
                    salon = 'SALON 308 A - PROYECTOS DE GRADO' if salon == 'SALON 308 A - PROYECTOS DE' else salon
                    salon = 'SALON DE PERCUSION SINFONICA' if salon == 'SALON DE PERCUSION' else salon
                    salon = 'SALON 110 TALLER TRIDIMENSIONAL' if salon == 'SALON 110 TALLER' else salon
                    
                    docente = re.search(' (ACADEMIA|CENTRO|POR ASIGNAR|SOTANOS) (PALACIO LA MERCED|CENTRO CULTURAL NUEVA|POR ASIGNAR|SOTANOS) (AUDITORIO PRINCIPAL|AUDITORIO SAMUEL BEDOYA|BIBLIOTECA|CENTRO DE PRODUCCION|HORNOS|LABORATORIO DE|PERCUSION ENSAMBLE|POR ASIGNAR|S\. PIEDRA A|S\.BIBLIOTEC|SALA DE EXPOSICIONES D 230|SALON DE INFORMATICA A 103|SALON \w [0-9]* \- SALA DIGITAL|SALON [0-9]* A \- PROYECTOS DE|SALON [0-9]* B \- CONSERJERIA|SALON \w [0-9]*|SALON J\-[0-9] \w|SALON \w\-[0-9]*|SALON DE PIANO [0-9]+|SALON DE PERCUSION|SALON DE MUSICA \w [0-9]+|SALON DEL RINCON|SALON MULTIPLE|SALON MUSICA [0-9]*|SALON [0-9]*|S\. [A-Z]+|TALLER DE CERAMICA B016|TALLER DE IMAGEN ESCENICA|TALLER [A-Z]+ [A-Z]+|TEATRINO SALON A 125|VITRALES A010) (.*)', linea)
                    try:                    
                        docente = docente.group(4)                    
                    except AttributeError:
                        docente = 'POR ASIGNAR'


                    json_constructor.append({"Proyecto_curricular": proyecto_curricular.group(1),
                                             "Grp": grp.group(1),
                                             "Espacio_Academico": espacio_Academico.group(1),
                                             "Cod": cod.group(),
                                             "Dia": dia.group(2),
                                             "Hora": hora.group(),
                                             "Sede": sede,
                                             "Edificio": edificio,
                                             "Salon": salon,
                                             "Docente": docente,
                                             "INSCRITOS": inscritos.group(1)})
        i += 1        
    pdf.close()    
f = open("prueba_facultad_artes_regex.json", 'w+')
f.write(json.dumps(json_constructor, indent=4, sort_keys=True))
f.close()

# %%
proyecto_curricular = ""x
espacio_Academico = ""
dia = ""
hora = ""
sede = ""
edificio = ""
salon = ""
docente = ""
grp = ""
inscritos = 0
cod = 0
json_constructor = []

with pdfplumber.open('horarios_20211_Segunda_Lengua.pdf') as pdf:        
    i = 0
    for pagina in pdf.pages:
        text = pagina.extract_text()
        if text is not None:
            for linea in text.split('\n'):                
                
                if re.search('PROYECTO CURRICULAR', linea): proyecto_curricular = re.search('PROYECTO CURRICULAR (.*)', linea)
                if re.search('GRP.', linea): grp = re.search('GRP\. (.*)', linea)
                if re.search('INSCRITOS', linea): inscritos = re.search('INSCRITOS (.*)', linea)
                if re.search('ESPACIO ACADEMICO', linea): espacio_Academico = re.search('ESPACIO ACADEMICO (.*)', linea)   
 
                if re.search('^[0-9]* ', linea) is not None:            
                    linea = re.sub("\s\s+", " ", linea) 
                    cod = re.search('^[0-9]*', linea)                
                    hora = re.search('.[0-9]\-[0-9]*', linea)
                    dia = re.search('^[0-9]+ (.*) (LUNES|MARTES|MIERCOLES|JUEVES|VIERNES|SABADO|DOMINGO)', linea)

                    sede = re.search(' (ACADEMIA|CALLE 34|CALLE 40|MACARENA \- A|POR ASIGNAR|PORVENIR|TECNOLOGICA|VIVERO)', linea)
                    sede = 'ACADEMIA SUPERIOR ARTES-ASAB' if sede.group(1) == 'ACADEMIA' else sede.group(1)

                    edificio = re.search(' (ACADEMIA|CALLE 34|CALLE 40|MACARENA \- A|POR ASIGNAR|PORVENIR|TECNOLOGICA|VIVERO) (_BLOQUE 2|ADMINISTRATIVO_VIVERO|ALEJANDRO SUAREZ COPETE|BLOQUE 1, 2, 3 Y 4 B\-[0-9]|BLOQUE 11-12|BLOQUE \d|CALLE 34|MACARENA A|NATURA|PALACIO LA MERCED|POR ASIGNAR|SABIO CALDAS)', linea)
                    salon = re.search(' (ACADEMIA|CALLE 34|CALLE 40|MACARENA \- A|POR ASIGNAR|PORVENIR|TECNOLOGICA|VIVERO) (_BLOQUE 2|ADMINISTRATIVO_VIVERO|ALEJANDRO SUAREZ COPETE|BLOQUE 1, 2, 3 Y 4 B\-[0-9]|BLOQUE 11-12|BLOQUE \d|CALLE 34|MACARENA A|NATURA|PALACIO LA MERCED|POR ASIGNAR|SABIO CALDAS) (SALON MUSICA 232|SALON DE MUSICA \w [0-9]*|SALON [0-9]* B \- CONSERJERIA |SALON \w [0-9]*|SALON [0-9]*|SALA DE TRABAJO|SALA 1|POR ASIGNAR|AULA CONVENCIONAL [0-9]*|AULA CONVENCIONAL \w\w|AULA MULTIPLE \d|AULA DE TRABAJO GRUPAL|AULA [0-9]*)', linea)
                    
                    docente = re.search(' (ACADEMIA|CALLE 34|CALLE 40|MACARENA \- A|POR ASIGNAR|PORVENIR|TECNOLOGICA|VIVERO) (_BLOQUE 2|ADMINISTRATIVO_VIVERO|ALEJANDRO SUAREZ COPETE|BLOQUE 1, 2, 3 Y 4 B\-[0-9]|BLOQUE 11-12|BLOQUE \d|CALLE 34|MACARENA A|NATURA|PALACIO LA MERCED|POR ASIGNAR|SABIO CALDAS) (SALON MUSICA 232|SALON DE MUSICA \w [0-9]*|SALON [0-9]* B \- CONSERJERIA |SALON \w [0-9]*|SALON [0-9]*|SALA DE TRABAJO|SALA 1|POR ASIGNAR|AULA CONVENCIONAL [0-9]*|AULA CONVENCIONAL \w\w|AULA MULTIPLE \d|AULA DE TRABAJO GRUPAL|AULA [0-9]*) (.*)', linea)
                    try:                    
                        docente = docente.group(4)                    
                    except AttributeError:
                        docente = 'POR ASIGNAR'
                    #print(str(i)+" "+inscritos.group(1))
                    json_constructor.append({"Proyecto_curricular": proyecto_curricular.group(1),
                                             "Grp": grp.group(1),
                                             "Espacio_Academico": espacio_Academico.group(1),
                                             "Cod": cod.group(),
                                             "Dia": dia.group(2),
                                             "Hora": hora.group(),
                                             "Sede": sede,
                                             "Edificio": edificio.group(2),
                                             "Salon": salon.group(3),
                                             "Docente": docente,
                                             "INSCRITOS": inscritos.group(1)})
        i += 1
    pdf.close()
f = open("prueba_segunda_lengua.json", 'w+')
f.write(json.dumps(json_constructor, indent=4, sort_keys=True))
f.close()

# %%
proyecto_curricular = ""s
espacio_Academico = ""
dia = ""
hora = ""
sede = ""
edificio = ""
salon = ""
docente = ""
grp = ""
inscritos = 0
cod = 0
json_constructor = []

with pdfplumber.open('horarios_20211_Facultad_Tecnologica.pdf') as pdf:        
    #pagina = pdf.pages[23]
    i = 0
    for pagina in pdf.pages:
        text = pagina.extract_text()
        if text is not None:
            for linea in text.split('\n'):                
                
                if re.search('PROYECTO CURRICULAR', linea): proyecto_curricular = re.search('PROYECTO CURRICULAR (.*)', linea)
                if re.search('GRP.', linea): grp = re.search('GRP\. (.*)', linea)
                if re.search('INSCRITOS', linea): inscritos = re.search('INSCRITOS (.*)', linea)
                if re.search('ESPACIO ACADEMICO', linea): espacio_Academico = re.search('ESPACIO ACADEMICO (.*)', linea)   
 
                if re.search('^[0-9]* ', linea) is not None:            
                    linea = re.sub("\s\s+", " ", linea) 
                    cod = re.search('^[0-9]*', linea)                
                    hora = re.search('.[0-9]\-[0-9].', linea)
                    dia = re.search('^[0-9]+ (.*) (LUNES|MARTES|MIERCOLES|JUEVES|VIERNES|SABADO|DOMINGO)', linea)

                    sede = re.search('\d (TECNOLOGICA) (.*)', linea)


                    edificio = re.search('\d TECNOLOGICA (AUDITORIO|BLOQUE 1, 2, 3 Y 4|BLOQUE 11\-12|BLOQUE 13 \- CAFETERIA|BLOQUE \d|MODULAR)', linea)
                    
                    salon = re.search('\d TECNOLOGICA (AUDITORIO|BLOQUE 1, 2, 3 Y 4|BLOQUE 11\-12|BLOQUE 13 \- CAFETERIA|BLOQUE \d|MODULAR) (TALLER DE [A-Z]*|SALON [0-9]*|SALA SOFTWARE|SALA DE SOFTWARE CIENCIAS|SALA DE SOFTWARE|SALA DE INFORMATICA \d|SALA 11|LPE-MC-02 LABORATORIO DE|LE - MC - 04 LABORATORIO DE|LABORATORIO SOFTWARE|LABORATORIO QUIMICA|LABORATORIO HIDRAULICA|LABORATORIO GEIO|LABORATORIO FISICA|LABORATORIO DE [A-Z]* Y|LABORATORIO DE [A-Z]*|LABORATORIO DE|LABORATORIO APLICADO DE|LABORATORIO ALTAMENTE|CUARTO OSCURO|B\-\d AULA DIBUJO [0-9]*|B\-\d AULA [0-9]*|AULA SOFTWARE|AULA MULTIPLE \d|AULA DIBUJO [0-9]*|AULA DE INFORMATICA \d|AULA [0-9]*|AUDITORIO|4\-[0-9]* LABORATORIO [A-Z]+|4\-[0-9]* LABORATORIO|LABORATORIO)', linea)
                    #if edificio.group(1) == "BLOQUE 5":
                    salon = 'SALA DE SOFTWARE APLICADO INGENIERIA CIVIL Y CONSTRUCCIONES CIVILES' if salon.group(2) == 'SALA DE SOFTWARE' and edificio.group(1) == "BLOQUE 5" and proyecto_curricular.group(1) == "CONV. SED - TECNOLOGIA CONSTRUC. CIVILES" else salon.group(2)
                    salon = 'SALA DE SOFTWARE APLICADO INGENIERIA CIVIL Y CONSTRUCCIONES CIVILES' if salon == 'SALA DE SOFTWARE' and edificio.group(1) == "BLOQUE 5" and proyecto_curricular.group(1) == "INGENIERIA CIVIL (CICLOS PROPEDEUTICOS)" else salon
                    salon = 'SALA DE SOFTWARE APLICADO INGENIERIA CIVIL Y CONSTRUCCIONES CIVILES' if salon == 'SALA DE SOFTWARE' and edificio.group(1) == "BLOQUE 5" and proyecto_curricular.group(1) == "TECNOLOGIA EN CONSTRUCCIONES CIVILES (CICLOS PROPEDEUTICOS)" else salon
                    salon = 'SALA DE SOFTWARE ESPECIALIZADO' if salon == 'SALA DE SOFTWARE' else salon
                    salon = 'SALA DE SOFTWARE CIENCIAS BASICAS' if salon == 'SALA DE SOFTWARE CIENCIAS' else salon
                    salon = 'LABORATORIO FISICA MECANICA, ELECTROMECANICA YTERMODINAMICA LCB - FT - 01' if salon == 'LABORATORIO FISICA' else salon
                    salon = 'LABORATORIO DE SUELOS Y PAVIMENTOS' if salon == 'LABORATORIO DE SUELOS Y' else salon
                    salon = 'LABORATORIO ALTAMENTE AUTOMATIZADO HAS-200' if salon == 'LABORATORIO ALTAMENTE' else salon
                    salon = 'LABORATORIO SOFTWARE APLICADO' if salon == 'LABORATORIO SOFTWARE' else salon
                    salon = 'LABORATORIO APLICADO DE INSTALACIONES ELECTRICAS E ILUMINACION' if salon == 'LABORATORIO APLICADO DE' else salon
                    salon = 'LABORATORIO ESPECIALIZADO DE ALTA TENSION Y ENSAYOS' if salon == 'LABORATORIO' else salon                    
                    salon = 'LABORATORIO QUIMICA BASICA' if salon == 'LABORATORIO QUIMICA' else salon
                    salon = 'LABORATORIO DE POLIMEROS Y PLASTICOS' if salon == 'LABORATORIO DE POLIMEROS' else salon
                    salon = 'LABORATORIO APLICADO DE CIRCUITOS ELECTRONICA Y CONTROL' if salon == 'LABORATORIO APLICADO DE' else salon
                    salon = 'LABORATORIO APLICADO DE MAQUINAS ELECTRICAS' if salon == 'LABORATORIO APLICADO DE' else salon
                    salon = '4-404 LABORATORIO ESPECIALIZADO CONTROL Y COMUNICACIONES' if salon == '4-404 LABORATORIO' else salon
                    salon = 'AULA SOFTWARE ESPECIALIZADO ELECTRONICA' if salon == 'AULA SOFTWARE' else salon
                    salon = '4-405 LABORATORIO PRACTICAS LIBRES' if salon == '4-405 LABORATORIO' else salon
                    salon = 'LE - MC - 04 LABORATORIO DE CIENCIAS TERMICAS' if salon == 'LE - MC - 04 LABORATORIO DE' else salon

                    
                    
                    if re.search('\d TECNOLOGICA (AUDITORIO|BLOQUE 1, 2, 3 Y 4|BLOQUE 11\-12|BLOQUE 13 \- CAFETERIA|BLOQUE \d|MODULAR) (TALLER DE [A-Z]*|SALON [0-9]*|SALA SOFTWARE|SALA DE SOFTWARE CIENCIAS|SALA DE SOFTWARE|SALA DE INFORMATICA \d|SALA 11|LPE-MC-02 LABORATORIO DE|LE - MC - 04 LABORATORIO DE|LABORATORIO SOFTWARE|LABORATORIO QUIMICA|LABORATORIO HIDRAULICA|LABORATORIO GEIO|LABORATORIO FISICA|LABORATORIO DE [A-Z]* Y|LABORATORIO DE [A-Z]*|LABORATORIO DE|LABORATORIO APLICADO DE|LABORATORIO ALTAMENTE|CUARTO OSCURO|B\-\d AULA DIBUJO [0-9]*|B\-\d AULA [0-9]*|AULA SOFTWARE|AULA MULTIPLE \d|AULA DIBUJO [0-9]*|AULA DE INFORMATICA \d|AULA [0-9]*|AUDITORIO|4\-[0-9]* LABORATORIO [A-Z]+|4\-[0-9]* LABORATORIO|LABORATORIO)', linea).group(2) == "LABORATORIO":
                        docente = re.search('\d TECNOLOGICA (AUDITORIO|BLOQUE 1, 2, 3 Y 4|BLOQUE 11\-12|BLOQUE 13 \- CAFETERIA|BLOQUE \d|MODULAR) (TALLER DE [A-Z]*|SALON [0-9]*|SALA SOFTWARE|SALA DE SOFTWARE CIENCIAS|SALA DE SOFTWARE|SALA DE INFORMATICA \d|SALA 11|LPE-MC-02 LABORATORIO DE|LE - MC - 04 LABORATORIO DE|LABORATORIO SOFTWARE|LABORATORIO QUIMICA|LABORATORIO HIDRAULICA|LABORATORIO GEIO|LABORATORIO FISICA|LABORATORIO DE [A-Z]* Y|LABORATORIO DE [A-Z]*|LABORATORIO DE|LABORATORIO APLICADO DE|LABORATORIO ALTAMENTE|CUARTO OSCURO|B\-\d AULA DIBUJO [0-9]*|B\-\d AULA [0-9]*|AULA SOFTWARE|AULA MULTIPLE \d|AULA DIBUJO [0-9]*|AULA DE INFORMATICA \d|AULA [0-9]*|AUDITORIO|4\-[0-9]* LABORATORIO [A-Z]+|4\-[0-9]* LABORATORIO|LABORATORIO) (.*)', linea)
                    else:
                        docente = re.search('\d TECNOLOGICA (AUDITORIO|BLOQUE 1, 2, 3 Y 4|BLOQUE 11\-12|BLOQUE 13 \- CAFETERIA|BLOQUE \d|MODULAR) (TALLER DE [A-Z]*|SALON [0-9]*|SALA SOFTWARE|SALA DE SOFTWARE CIENCIAS|SALA DE SOFTWARE|SALA DE INFORMATICA \d|SALA 11|LPE-MC-02 LABORATORIO DE|LE - MC - 04 LABORATORIO DE|LABORATORIO SOFTWARE|LABORATORIO QUIMICA|LABORATORIO HIDRAULICA|LABORATORIO GEIO|LABORATORIO FISICA|LABORATORIO DE [A-Z]* Y|LABORATORIO DE [A-Z]*|LABORATORIO DE|LABORATORIO APLICADO DE|LABORATORIO ALTAMENTE|CUARTO OSCURO|B\-\d AULA DIBUJO [0-9]*|B\-\d AULA [0-9]*|AULA SOFTWARE|AULA MULTIPLE \d|AULA DIBUJO [0-9]*|AULA DE INFORMATICA \d|AULA [0-9]*|AUDITORIO|4\-[0-9]* LABORATORIO [A-Z]+|4\-[0-9]* LABORATORIO) (.*)', linea)
                    try:                    
                        docente = docente.group(3)
                    except AttributeError:
                        docente = 'POR ASIGNAR'
                    #str(i)+" "+
                    #print(str(i)+" "+salon)
                    json_constructor.append({"Proyecto_curricular": proyecto_curricular.group(1),
                                             "Grp": grp.group(1),
                                             "Espacio_Academico": espacio_Academico.group(1),
                                             "Cod": cod.group(),
                                             "Dia": dia.group(2),
                                             "Hora": hora.group(),
                                             "Sede": sede.group(1),
                                             "Edificio": edificio.group(1),
                                             "Salon": salon,
                                             "Docente": docente,
                                             "INSCRITOS": inscritos.group(1)})
        i += 1        
    pdf.close()    
f = open("prueba_facultad_tecnologica_regex.json", 'w+')
f.write(json.dumps(json_constructor, indent=4, sort_keys=True))
f.close()

# %%
proyecto_curricular = ""x
espacio_Academico = ""
dia = ""
hora = ""
sede = ""
edificio = ""
salon = ""
docente = ""
grp = ""
inscritos = 0
cod = 0
json_constructor = []

with pdfplumber.open('horarios_20211_Facultad_Medio_Ambiente.pdf') as pdf:        
    #pagina = pdf.pages[23]
    i = 0
    for pagina in pdf.pages:
        text = pagina.extract_text()
        if text is not None:
            for linea in text.split('\n'):                
                linea = re.sub("\s\s+", " ", linea) 
                if re.search('PROYECTO CURRICULAR', linea): proyecto_curricular = re.search('PROYECTO CURRICULAR (.*)', linea)
                if re.search('GRP.', linea): grp = re.search('GRP\. (.*)', linea)
                if re.search('INSCRITOS', linea): inscritos = re.search('INSCRITOS (.*)', linea)
                if re.search('ESPACIO ACADEMICO', linea): espacio_Academico = re.search('ESPACIO ACADEMICO (.*)', linea)   
 
                if re.search('^[0-9]* ', linea) is not None:            
                    
                    cod = re.search('^[0-9]*', linea)                
                    hora = re.search('.[0-9]\-[0-9]*', linea)
                    dia = re.search('^[0-9]+ (.*) (LUNES|MARTES|MIERCOLES|JUEVES|VIERNES|SABADO|DOMINGO)', linea)

                    sede = re.search('\d (MACARENA \- A|CALLE 34|VIVERO|MODALIDAD|POR ASIGNAR|PORVENIR)', linea)
                    sede = "MODALIDAD VIRTUAL" if sede.group(1) == "MODALIDAD VIRTUAL" else sede.group(1)
                    edificio = re.search('\d (MACARENA \- A|CALLE 34|VIVERO|MODALIDAD|POR ASIGNAR|PORVENIR) (POR ASIGNAR|NATURA|MODALIDAD VIRTUAL|LABORATORIO DE [A-Z]*|CALLE 34|BLOQUE \d|ADMINISTRATIVO_VIVERO|_BLOQUE \d)', linea)

                    salon = re.search('\d (MACARENA \- A|CALLE 34|VIVERO|MODALIDAD|POR ASIGNAR|PORVENIR) (POR ASIGNAR|NATURA|MODALIDAD VIRTUAL|LABORATORIO DE [A-Z]*|CALLE 34|BLOQUE \d|ADMINISTRATIVO_VIVERO|_BLOQUE \d) (SALA MULTIPLE|SALA AUDIOV|SALA \d|S\. SIST 106|POR ASIGNAR|LABORATORIO DE QUIMICA|LABORATORIO DE FISICA \d\w|LABORATORIO DE FISICA|LABORATORIO DE ECOLOGIA|LABORATORIO DE BIOLOGIA|LABORATORIO DE|LABORATORIO CALIDAD DEL|LABORATORIO CALIDAD DE|COORDINACION|COMEDOR|CIRCULACION Y PRESTAMO|AULA VIRTUAL MTCM 3|AULA VIRTUAL MTCM|AULA MAGISTRAL [0-9]+|AULA DE TRABAJO GRUPAL|AULA DE SISTEMAS [0-9]*|AULA CONVENCIONAL [0-9]*|AULA [0-9]*|AUDITORIO PRINCIPAL 101|AUDITORIO PRINCIPAL 101|AUDITORIO|ALMACEN DE TOPOGRAFIA|ADMINISTRACION SALAS)', linea)
                    salon = 'COORDINACION ADMINISTRACION DEPORTIVA' if salon.group(3) == 'COORDINACION' else salon.group(3)
                    salon = 'LABORATORIO CALIDAD DEL AGUA' if salon == 'LABORATORIO CALIDAD DEL' else salon
                    salon = 'LABORATORIO CALIDAD DE AGUAS' if salon == 'LABORATORIO CALIDAD DE' else salon
                    salon = 'LABORATORIO CALIDAD DEL AIRE' if salon == 'LABORATORIO CALIDAD DEL' and espacio_Academico.group(1) == "EMISIONES ATMOSFERICAS" or espacio_Academico.group(1) == "CONTAMINACION AMBIENTAL II" else salon
                    salon = 'LABORATORIO CALIDAD DEL AIRE' if salon == 'LABORATORIO CALIDAD DEL' and espacio_Academico.group(1) == "CONTAMINACION AMBIENTAL II"  or espacio_Academico.group(1) == "EMISIONES ATMOSFERICAS" else salon
                    salon = 'LABORATORIO DE MICROBIOLOGIA Y BIOPROSPECCION MEDIOAMBIENTAL' if salon == 'LABORATORIO DE' and espacio_Academico.group(1) == "BIOLOGIA GENERAL" or espacio_Academico.group(1) == "MICROBIOLOGIA" else salon 
                    salon = 'LABORATORIO DE CARTOGRAFIA' if salon == 'LABORATORIO DE' and espacio_Academico.group(1) == "CARTOGRAFIA" or espacio_Academico.group(1) == "HIDROLOGIA" or espacio_Academico.group(1) == "CARTOGRAFIA DIGITAL" or espacio_Academico.group(1) == "BASES DE DATOS ESPACIALES" or espacio_Academico.group(1) == "PERCEPCION REMOTA" or espacio_Academico.group(1) == "TOPOGRAFIA AUTOMATIZADA" or espacio_Academico.group(1) == "CARTOGRAFIA DIGITAL AVANZADA" or espacio_Academico.group(1) == "LOGICA DE PROGRAMACION" or espacio_Academico.group(1) == "LEVANTAMIENTOS ALTIMETRICOS" or espacio_Academico.group(1) == "LEVANTAMIENTOS ASTRONOMICOS"  or  espacio_Academico.group(1) == "LEVANTAMIENTOS FOTOGRAMETRICOS" or espacio_Academico.group(1) == "FOTOGRAFIA I" else salon 
                    salon = 'LABORATORIO DE FOTOINTERPRETACION' if salon == 'LABORATORIO DE' and espacio_Academico.group(1) == "ORDENACION DE CUENCAS" or espacio_Academico.group(1) == "PERCEPCION REMOTA E INTERPRETACION DE IMAGENES" or espacio_Academico.group(1) == "CUENCAS HIDROGRAFICAS" or espacio_Academico.group(1) == "GEOMETRIA DESCRIPTIVA" or espacio_Academico.group(1) == "FOTOGRAMETRIA Y FOTOINTERPRETACION" else salon 
                    salon = 'LABORATORIO DE QUIMICA GENERAL' if salon == 'LABORATORIO DE QUIMICA' else salon
                    salon = 'LABORATORIO DE MICROBIOLOGIA' if salon == 'LABORATORIO DE' and espacio_Academico.group(1) == "PROCESOS BIOLOGICOS" or espacio_Academico.group(1) == "GESTION DE INOCUIDAD" or espacio_Academico.group(1) == "MICROBIOLOGIA" or espacio_Academico.group(1) == "BIOTECNOLOGIA" or espacio_Academico.group(1) == "MANEJO E HIGIENE DE ALIMENTOS" else salon 
                    salon = 'LABORATORIO DE QUIMICA ORGANICA' if salon == 'LABORATORIO DE QUIMICA' and espacio_Academico.group(1) == "FUNDAMENTOS DE QUIMICA" or espacio_Academico.group(1) == "QUIMICA ORGANICA" or espacio_Academico.group(1) == "BIOQUIMICA" or espacio_Academico.group(1) == "FISICO-QUIMICA" else salon
                    salon = 'LABORATORIO DE SILVICULTURA' if salon == 'LABORATORIO DE' and espacio_Academico.group(1) == "ARBORICULTURA URBANA" or espacio_Academico.group(1) == "FITOMEJORAMIENTO FORESTAL" else salon 
                    salon = 'LABORATORIO DE TECNOLOGIAS LIMPIAS' if salon == 'LABORATORIO DE' and espacio_Academico.group(1) == "TECNOLOGIAS APROPIADAS II" else salon 
                    salon = 'LABORATORIO DE ECOLOGIA Y ZOONOSIS' if salon == 'LABORATORIO DE ECOLOGIA' else salon
                    #salon = '' if salon == '' else salon
                    
                    if re.search('\d (MACARENA \- A|CALLE 34|VIVERO|MODALIDAD|POR ASIGNAR|PORVENIR) (POR ASIGNAR|NATURA|MODALIDAD VIRTUAL|LABORATORIO DE [A-Z]*|CALLE 34|BLOQUE \d|ADMINISTRATIVO_VIVERO|_BLOQUE \d) (SALA MULTIPLE|SALA AUDIOV|SALA \d|S\. SIST 106|POR ASIGNAR|LABORATORIO DE QUIMICA|LABORATORIO DE FISICA|LABORATORIO DE ECOLOGIA|LABORATORIO DE BIOLOGIA|LABORATORIO DE|LABORATORIO CALIDAD DEL|LABORATORIO CALIDAD DE|COORDINACION|COMEDOR|CIRCULACION Y PRESTAMO|AULA VIRTUAL MTCM 3|AULA VIRTUAL MTCM|AULA MAGISTRAL [0-9]+|AULA DE TRABAJO GRUPAL|AULA DE SISTEMAS [0-9]*|AULA CONVENCIONAL [0-9]*|AULA [0-9]*|AUDITORIO PRINCIPAL 101|AUDITORIO|ALMACEN DE TOPOGRAFIA|ADMINISTRACION SALAS)', linea) == "LABORATORIO DE FISICA":
                        docente = re.search('\d (MACARENA \- A|CALLE 34|VIVERO|MODALIDAD|POR ASIGNAR|PORVENIR) (POR ASIGNAR|NATURA|MODALIDAD VIRTUAL|LABORATORIO DE [A-Z]*|CALLE 34|BLOQUE \d|ADMINISTRATIVO_VIVERO|_BLOQUE \d) (SALA MULTIPLE|SALA AUDIOV|SALA \d|S\. SIST 106|POR ASIGNAR|LABORATORIO DE QUIMICA|LABORATORIO DE FISICA|LABORATORIO DE ECOLOGIA|LABORATORIO DE BIOLOGIA|LABORATORIO DE|LABORATORIO CALIDAD DEL|LABORATORIO CALIDAD DE|COORDINACION|COMEDOR|CIRCULACION Y PRESTAMO|AULA VIRTUAL MTCM 3|AULA VIRTUAL MTCM|AULA MAGISTRAL [0-9]+|AULA DE TRABAJO GRUPAL|AULA DE SISTEMAS [0-9]*|AULA CONVENCIONAL [0-9]*|AULA [0-9]*|AUDITORIO PRINCIPAL 101|AUDITORIO|ALMACEN DE TOPOGRAFIA|ADMINISTRACION SALAS) (.*)', linea)
                    else:
                        docente = re.search('\d (MACARENA \- A|CALLE 34|VIVERO|MODALIDAD|POR ASIGNAR|PORVENIR) (POR ASIGNAR|NATURA|MODALIDAD VIRTUAL|LABORATORIO DE [A-Z]*|CALLE 34|BLOQUE \d|ADMINISTRATIVO_VIVERO|_BLOQUE \d) (SALA MULTIPLE|SALA AUDIOV|SALA \d|S\. SIST 106|POR ASIGNAR|LABORATORIO DE QUIMICA|LABORATORIO DE FISICA \d\w|LABORATORIO DE ECOLOGIA|LABORATORIO DE BIOLOGIA|LABORATORIO DE|LABORATORIO CALIDAD DEL|LABORATORIO CALIDAD DE|COORDINACION|COMEDOR|CIRCULACION Y PRESTAMO|AULA VIRTUAL MTCM 3|AULA VIRTUAL MTCM|AULA MAGISTRAL [0-9]+|AULA DE TRABAJO GRUPAL|AULA DE SISTEMAS [0-9]*|AULA CONVENCIONAL [0-9]*|AULA [0-9]*|AUDITORIO PRINCIPAL 101|AUDITORIO|ALMACEN DE TOPOGRAFIA|ADMINISTRACION SALAS) (.*)', linea)
                    if re.search('\d (MACARENA \- A|CALLE 34|VIVERO|MODALIDAD|POR ASIGNAR|PORVENIR) (POR ASIGNAR|NATURA|MODALIDAD VIRTUAL|LABORATORIO DE [A-Z]*|CALLE 34|BLOQUE \d|ADMINISTRATIVO_VIVERO|_BLOQUE \d) (SALA MULTIPLE|SALA AUDIOV|SALA \d|S\. SIST 106|POR ASIGNAR|LABORATORIO DE QUIMICA|LABORATORIO DE FISICA|LABORATORIO DE ECOLOGIA|LABORATORIO DE BIOLOGIA|LABORATORIO DE|LABORATORIO CALIDAD DEL|LABORATORIO CALIDAD DE|COORDINACION|COMEDOR|CIRCULACION Y PRESTAMO|AULA VIRTUAL MTCM 3|AULA VIRTUAL MTCM|AULA MAGISTRAL [0-9]+|AULA DE TRABAJO GRUPAL|AULA DE SISTEMAS [0-9]*|AULA CONVENCIONAL [0-9]*|AULA [0-9]*|AUDITORIO PRINCIPAL 101|AUDITORIO|ALMACEN DE TOPOGRAFIA|ADMINISTRACION SALAS)', linea) == "AULA VIRTUAL MTCM":
                        docente = re.search('\d (MACARENA \- A|CALLE 34|VIVERO|MODALIDAD|POR ASIGNAR|PORVENIR) (POR ASIGNAR|NATURA|MODALIDAD VIRTUAL|LABORATORIO DE [A-Z]*|CALLE 34|BLOQUE \d|ADMINISTRATIVO_VIVERO|_BLOQUE \d) (SALA MULTIPLE|SALA AUDIOV|SALA \d|S\. SIST 106|POR ASIGNAR|LABORATORIO DE QUIMICA|LABORATORIO DE FISICA|LABORATORIO DE ECOLOGIA|LABORATORIO DE BIOLOGIA|LABORATORIO DE|LABORATORIO CALIDAD DEL|LABORATORIO CALIDAD DE|COORDINACION|COMEDOR|CIRCULACION Y PRESTAMO|AULA VIRTUAL MTCM|AULA MAGISTRAL [0-9]+|AULA DE TRABAJO GRUPAL|AULA DE SISTEMAS [0-9]*|AULA CONVENCIONAL [0-9]*|AULA [0-9]*|AUDITORIO PRINCIPAL 101|AUDITORIO|ALMACEN DE TOPOGRAFIA|ADMINISTRACION SALAS) (.*)', linea)
                    else:
                        docente = re.search('\d (MACARENA \- A|CALLE 34|VIVERO|MODALIDAD|POR ASIGNAR|PORVENIR) (POR ASIGNAR|NATURA|MODALIDAD VIRTUAL|LABORATORIO DE [A-Z]*|CALLE 34|BLOQUE \d|ADMINISTRATIVO_VIVERO|_BLOQUE \d) (SALA MULTIPLE|SALA AUDIOV|SALA \d|S\. SIST 106|POR ASIGNAR|LABORATORIO DE QUIMICA|LABORATORIO DE FISICA \d\w|LABORATORIO DE ECOLOGIA|LABORATORIO DE BIOLOGIA|LABORATORIO DE|LABORATORIO CALIDAD DEL|LABORATORIO CALIDAD DE|COORDINACION|COMEDOR|CIRCULACION Y PRESTAMO|AULA VIRTUAL MTCM 3|AULA MAGISTRAL [0-9]+|AULA DE TRABAJO GRUPAL|AULA DE SISTEMAS [0-9]*|AULA CONVENCIONAL [0-9]*|AULA [0-9]*|AUDITORIO PRINCIPAL 101|AUDITORIO|ALMACEN DE TOPOGRAFIA|ADMINISTRACION SALAS) (.*)', linea)
                    try:                    
                        docente = docente.group(4)                    
                    except AttributeError:
                        docente = 'POR ASIGNAR'

                    json_constructor.append({"Proyecto_curricular": proyecto_curricular.group(1),
                                             "Grp": grp.group(1),
                                             "Espacio_Academico": espacio_Academico.group(1),
                                             "Cod": cod.group(),
                                             "Dia": dia.group(2),
                                             "Hora": hora.group(),
                                             "Sede": sede,
                                             "Edificio": edificio.group(2),
                                             "Salon": salon,
                                             "Docente": docente,
                                             "INSCRITOS": inscritos.group(1)})
        i += 1        
    pdf.close()    
f = open("prueba_facultad_medio_ambiente_regex.json", 'w+')
f.write(json.dumps(json_constructor, indent=4, sort_keys=True))
f.close()

# %%
proyecto_curricular = ""z
espacio_Academico = ""
dia = ""
hora = ""
sede = ""
edificio = ""
salon = ""
docente = ""
grp = ""
inscritos = 0
cod = 0
json_constructor = []

with pdfplumber.open('horarios_20211_Facultad_Ingenieria.pdf') as pdf:        
    #pagina = pdf.pages[23]
    i = 0
    for pagina in pdf.pages:
        text = pagina.extract_text()
        if text is not None:
            for linea in text.split('\n'):                
                
                if re.search('PROYECTO CURRICULAR', linea): proyecto_curricular = re.search('PROYECTO CURRICULAR (.*)', linea)
                if re.search('GRP.', linea): grp = re.search('GRP\. (.*)', linea)
                if re.search('INSCRITOS', linea): inscritos = re.search('INSCRITOS (.*)', linea)
                if re.search('ESPACIO ACADEMICO', linea): espacio_Academico = re.search('ESPACIO ACADEMICO (.*)', linea)   
                linea = re.sub("\s\s+", " ", linea) 
                if re.search('^[0-9]* ', linea) is not None:            
                    
                    cod = re.search('^[0-9]*', linea)                
                    hora = re.search('.[0-9]\-[0-9]* (.*)', linea)
                    dia = re.search('^[0-9]+ (.*) (LUNES|MARTES|MIERCOLES|JUEVES|VIERNES|SABADO|DOMINGO)', linea)

                    sede = re.search('\d (MACARENA \- \w|TECNOLOGICA|POR ASIGNAR|CALLE [0-9]*|ADUANILLA DE)', linea)
                    sede = 'ADUANILLA DE PAIBA' if sede.group(1) == 'ADUANILLA DE' else sede.group(1)                                        
                    edificio = re.search('\d (MACARENA \- \w|TECNOLOGICA|POR ASIGNAR|CALLE [0-9]*|ADUANILLA DE) (SABIO CALDAS|POR ASIGNAR|OBSERVATORIO|LABORATORIOS|CALLE 34|BLOQUE 1, 2, 3 Y 4|BLOQUE \d|ALEJANDRO SUAREZ COPETE)', linea)


                    salon = re.search('\d (MACARENA \- \w|TECNOLOGICA|POR ASIGNAR|CALLE [0-9]*|ADUANILLA DE) (SABIO CALDAS|POR ASIGNAR|OBSERVATORIO|LABORATORIOS|CALLE 34|BLOQUE 1, 2, 3 Y 4|BLOQUE \d|ALEJANDRO SUAREZ COPETE) (SALA DE INFORMATICA [0-9]*|SALA DE INFORM\?TICA [0-9]*|SALA AUDIOV|POR ASIGNAR|LE \- MC \- 03 LABORATORIO|LABORATORIO QUIMICA \d|LABORATORIO ELECTRONICA|LABORATORIO DIGITALES|LABORATORIO DE MAQUINAS|LABORATORIO DE HIDRAULICA|LABORATORIO DE FISICA \d\w|LABORATORIO DE FISICA [0-9]*|LABORATORIO DE|LABORATORIO CIRCUITOS|LABORATORIO BIOLOGIA \d|LABORATORIO|AULA DE INFORMATICA 601|AULA [0-9]*|AUDITORIO|AREA DE TRABAJO \d)', linea)
                    salon = 'LE - MC - 03 LABORATORIO CNC Y ROBOTICA' if salon.group(3) == 'LE - MC - 03 LABORATORIO' else salon.group(3)
                    salon = 'LABORATORIO ELECTRONICA BASICA' if salon == 'LABORATORIO ELECTRONICA' and  espacio_Academico.group(1) == "ELECTRONICA I" or espacio_Academico.group(1) == "MAQUINAS ELECTRICAS" or espacio_Academico.group(1) == "ANALISIS DE CIRCUITOS I Y LABORATORIO" or espacio_Academico.group(1) == "TRANSFORMADORES" or espacio_Academico.group(1) == "COMUNICACIONES ANALOGICAS" or espacio_Academico.group(1) == "ELECTRONICA DE POTENCIA"  else salon
                    salon = 'LABORATORIO ELECTRONICA A' if salon == 'LABORATORIO ELECTRONICA' and  espacio_Academico.group(1) == "ELECTRONICA II" or espacio_Academico.group(1) == "INSTRUMENTACION Y MEDIDAS" or espacio_Academico.group(1) == "TRANSPORTE DE ENERGIA" or espacio_Academico.group(1) == "ANALISIS DE CIRCUITOS II Y LABORATORIO" or espacio_Academico.group(1) == "ELECTRONICA III" or espacio_Academico.group(1) == "DISE?O DIGITAL CON MICROCONTROLADORES" or espacio_Academico.group(1) == "INSTRUMENTACION INDUSTRIAL" or espacio_Academico.group(1) == "BIOINGENIERIA I" or espacio_Academico.group(1) == "BIOINGENIERIA II" else salon
                    salon = 'LABORATORIO DE HIDRAULICA Y NEUMATICA' if salon == 'LABORATORIO DE HIDRAULICA' else salon
                    salon = 'LABORATORIO DE FOTOGRAMETRIA DIGITAL' if salon == 'LABORATORIO DE' else salon
                    salon = 'LABORATORIO COMUNICACIONES' if salon == 'LABORATORIO' and espacio_Academico.group(1) == "CIRCUITOS I" or espacio_Academico.group(1) == "ELECTRONICA I" or espacio_Academico.group(1) == "ELECTRONICA DIGITAL" or espacio_Academico.group(1) == "ANALISIS DE CIRCUITOS I Y LABORATORIO" or espacio_Academico.group(1) == "COMUNICACIONES ANALOGICAS" or espacio_Academico.group(1) == "COMUNICACIONES DIGITALES" or espacio_Academico.group(1) == "TELECOMUNICACIONES I" or espacio_Academico.group(1) == "TELECOMUNICACIONES II" or espacio_Academico.group(1) == "TELECOMUNICACIONES III" or espacio_Academico.group(1) == "ELECTRONICA I" else salon
                    salon = 'LABORATORIO FOTOGRAMETRIA Y CARTOGRAFIA' if salon == 'laboratorio ' and espacio_Academico.group(1) == "FOTOGRAMETRIA" or  espacio_Academico.group(1) == "PERCEPCION REMOTA E INTERPRETACION DE IMAGENES" or  espacio_Academico.group(1) == "TRABAJO DE GRADO I: METODOLOGIA DE LA INVESTIGACION" else salon

                    if re.search('\d (MACARENA \- \w|TECNOLOGICA|POR ASIGNAR|CALLE [0-9]*|ADUANILLA DE) (SABIO CALDAS|POR ASIGNAR|OBSERVATORIO|LABORATORIOS|CALLE 34|BLOQUE 1, 2, 3 Y 4|BLOQUE \d|ALEJANDRO SUAREZ COPETE) (SALA DE INFORMATICA [0-9]*|SALA DE INFORM\?TICA [0-9]*|SALA AUDIOV|POR ASIGNAR|LE \- MC \- 03 LABORATORIO|LABORATORIO QUIMICA \d|LABORATORIO ELECTRONICA|LABORATORIO DIGITALES|LABORATORIO DE MAQUINAS|LABORATORIO DE HIDRAULICA|LABORATORIO DE FISICA \d\w|LABORATORIO DE FISICA [0-9]*|LABORATORIO DE|LABORATORIO CIRCUITOS|LABORATORIO BIOLOGIA \d|LABORATORIO|AULA DE INFORMATICA 601|AULA [0-9]*|AUDITORIO|AREA DE TRABAJO \d)', linea).group(3) == "LABORATORIO":
                        docente = re.search('\d (MACARENA \- \w|TECNOLOGICA|POR ASIGNAR|CALLE [0-9]*|ADUANILLA DE) (SABIO CALDAS|POR ASIGNAR|OBSERVATORIO|LABORATORIOS|CALLE 34|BLOQUE 1, 2, 3 Y 4|BLOQUE \d|ALEJANDRO SUAREZ COPETE) (SALA DE INFORMATICA [0-9]*|SALA DE INFORM\?TICA [0-9]*|SALA AUDIOV|POR ASIGNAR|LE \- MC \- 03 LABORATORIO|LABORATORIO QUIMICA \d|LABORATORIO ELECTRONICA|LABORATORIO DIGITALES|LABORATORIO DE MAQUINAS|LABORATORIO DE HIDRAULICA|LABORATORIO DE FISICA \d\w|LABORATORIO DE FISICA [0-9]*|LABORATORIO DE|LABORATORIO CIRCUITOS|LABORATORIO BIOLOGIA \d|LABORATORIO|AULA DE INFORMATICA 601|AULA [0-9]*|AUDITORIO|AREA DE TRABAJO \d) (.*)', linea)
                    else: 
                        docente = re.search('\d (MACARENA \- \w|TECNOLOGICA|POR ASIGNAR|CALLE [0-9]*|ADUANILLA DE) (SABIO CALDAS|POR ASIGNAR|OBSERVATORIO|LABORATORIOS|CALLE 34|BLOQUE 1, 2, 3 Y 4|BLOQUE \d|ALEJANDRO SUAREZ COPETE) (SALA DE INFORMATICA [0-9]*|SALA DE INFORM\?TICA [0-9]*|SALA AUDIOV|POR ASIGNAR|LE \- MC \- 03 LABORATORIO|LABORATORIO QUIMICA \d|LABORATORIO ELECTRONICA|LABORATORIO DIGITALES|LABORATORIO DE MAQUINAS|LABORATORIO DE HIDRAULICA|LABORATORIO DE FISICA \d\w|LABORATORIO DE FISICA [0-9]*|LABORATORIO DE|LABORATORIO CIRCUITOS|LABORATORIO BIOLOGIA \d|AULA DE INFORMATICA 601|AULA [0-9]*|AUDITORIO|AREA DE TRABAJO \d) (.*)', linea)
                    if re.search('\d (MACARENA \- \w|TECNOLOGICA|POR ASIGNAR|CALLE [0-9]*|ADUANILLA DE) (SABIO CALDAS|POR ASIGNAR|OBSERVATORIO|LABORATORIOS|CALLE 34|BLOQUE 1, 2, 3 Y 4|BLOQUE \d|ALEJANDRO SUAREZ COPETE) (SALA DE INFORMATICA [0-9]*|SALA DE INFORM\?TICA [0-9]*|SALA AUDIOV|POR ASIGNAR|LE \- MC \- 03 LABORATORIO|LABORATORIO QUIMICA \d|LABORATORIO ELECTRONICA|LABORATORIO DIGITALES|LABORATORIO DE MAQUINAS|LABORATORIO DE HIDRAULICA|LABORATORIO DE FISICA \d\w|LABORATORIO DE FISICA [0-9]*|LABORATORIO DE|LABORATORIO CIRCUITOS|LABORATORIO BIOLOGIA \d|LABORATORIO|AULA DE INFORMATICA 601|AULA [0-9]*|AUDITORIO|AREA DE TRABAJO \d)', linea).group(3) == "LABORATORIO DE":       
                        docente = re.search('\d (MACARENA \- \w|TECNOLOGICA|POR ASIGNAR|CALLE [0-9]*|ADUANILLA DE) (SABIO CALDAS|POR ASIGNAR|OBSERVATORIO|LABORATORIOS|CALLE 34|BLOQUE 1, 2, 3 Y 4|BLOQUE \d|ALEJANDRO SUAREZ COPETE) (SALA DE INFORMATICA [0-9]*|SALA DE INFORM\?TICA [0-9]*|SALA AUDIOV|POR ASIGNAR|LE \- MC \- 03 LABORATORIO|LABORATORIO QUIMICA \d|LABORATORIO ELECTRONICA|LABORATORIO DIGITALES|LABORATORIO DE MAQUINAS|LABORATORIO DE HIDRAULICA|LABORATORIO DE FISICA \d\w|LABORATORIO DE FISICA [0-9]*|LABORATORIO DE|LABORATORIO CIRCUITOS|LABORATORIO BIOLOGIA \d|LABORATORIO|AULA DE INFORMATICA 601|AULA [0-9]*|AUDITORIO|AREA DE TRABAJO \d) (.*)', linea)
                    else: 
                        docente = re.search('\d (MACARENA \- \w|TECNOLOGICA|POR ASIGNAR|CALLE [0-9]*|ADUANILLA DE) (SABIO CALDAS|POR ASIGNAR|OBSERVATORIO|LABORATORIOS|CALLE 34|BLOQUE 1, 2, 3 Y 4|BLOQUE \d|ALEJANDRO SUAREZ COPETE) (SALA DE INFORMATICA [0-9]*|SALA DE INFORM\?TICA [0-9]*|SALA AUDIOV|POR ASIGNAR|LE \- MC \- 03 LABORATORIO|LABORATORIO QUIMICA \d|LABORATORIO ELECTRONICA|LABORATORIO DIGITALES|LABORATORIO DE MAQUINAS|LABORATORIO DE HIDRAULICA|LABORATORIO DE FISICA \d\w|LABORATORIO DE FISICA [0-9]*|LABORATORIO CIRCUITOS|LABORATORIO BIOLOGIA \d|AULA DE INFORMATICA 601|AULA [0-9]*|AUDITORIO|AREA DE TRABAJO \d) (.*)', linea)                    
                    try:                    
                        docente = docente.group(4)                    
                    except AttributeError:
                        docente = 'POR ASIGNAR'
                    #str(i)+" "+
                    #rint(str(i)+" "+edificio.group(2))
                    json_constructor.append({"Proyecto_curricular": proyecto_curricular.group(1),
                                             "Grp": grp.group(1),
                                             "Espacio_Academico": espacio_Academico.group(1),
                                             "Cod": cod.group(),
                                             "Dia": dia.group(2),
                                             "Hora": hora.group(),
                                             "Sede": sede,
                                             "Edificio": edificio.group(2),
                                             "Salon": salon,
                                             "Docente": docente,
                                             "INSCRITOS": inscritos.group(1)})
        i += 1
    pdf.close()    
f = open("prueba_facultad_ingenieria_regex.json", 'w+')
f.write(json.dumps(json_constructor, indent=4, sort_keys=True))
f.close()

# %%
proyecto_curricular = ""
espacio_Academico = ""
dia = ""
hora = ""
sede = ""
edificio = ""
salon = ""
docente = ""
grp = ""
inscritos = 0
cod = 0
json_constructor = []

with pdfplumber.open('horarios_20211_Facultad_Ciencias.pdf') as pdf:        
    #pagina = pdf.pages[23]
    i = 0
    for pagina in pdf.pages:
        text = pagina.extract_text()
        if text is not None:
            for linea in text.split('\n'):                
                
                if re.search('PROYECTO CURRICULAR', linea): proyecto_curricular = re.search('PROYECTO CURRICULAR (.*)', linea)
                if re.search('GRP.', linea): grp = re.search('GRP\. (.*)', linea)
                if re.search('INSCRITOS', linea): inscritos = re.search('INSCRITOS (.*)', linea)
                if re.search('ESPACIO ACADEMICO', linea): espacio_Academico = re.search('ESPACIO ACADEMICO (.*)', linea)   
                linea = re.sub("\s\s+", " ", linea) 
                if re.search('^[0-9]* ', linea) is not None:            
                    
                    cod = re.search('^[0-9]*', linea)                
                    hora = re.search('.[0-9]\-[0-9]* (.*)', linea)                    
                    dia = re.search('^[0-9]+ (.*) (LUNES|MARTES|MIERCOLES|JUEVES|VIERNES|SABADO|DOMINGO)', linea)

                    sede = re.search('\d (MACARENA \- \w|POSTGRADOS|PORVENIR|POR ASIGNAR)', linea)                    
                    edificio = re.search('\d (MACARENA \- \w|POSTGRADOS|PORVENIR|POR ASIGNAR) (PRACTICAS EXTERNAS|POR ASIGNAR|MONJAS|MACARENA A|LABORATORIOS|BLOQUE \d*|_BLOQUE 3)', linea)


                    salon = re.search('\d (MACARENA \- \w|POSTGRADOS|PORVENIR|POR ASIGNAR) (PRACTICAS EXTERNAS|POR ASIGNAR|MONJAS|MACARENA A|LABORATORIOS|BLOQUE \d*|_BLOQUE 3) (TALLER DE GRABADO|TALLER DE ARTES PLASTICAS|SALA DE TUTORIAS Y|SALA DE SISTEMAS|SALA DE INFORMATICA|POR ASIGNAR|LABORATORIO QUIMICA \d|LABORATORIO DE FISICA \d\w|LABORATORIO DE BIOLOGIA 4|LABORATORIO BIOLOGIA \d|LAB\. DIDACT|INSTRUMENTAL N\? 1|EXTERNO [0-9]*|AULA MAGISTRAL [0-9]*|AULA EXPERIMENTAL|AULA DE TRABAJO GRUPAL|AULA DE SISTEMAS [0-9]*|AULA CONVENCIONAL 10A|AULA CONVENCIONAL \d\w|AULA CONVENCIONAL [0-9]*|AULA ARTES VISUALES 703|AULA ARTES MUSICALES [0-9]*|AULA ARTES ESCENICAS \-|AULA [0-9]*|AUDITORIO PRINCIPAL [0-9]*|AUDITORIO PRINCIPAL)', linea)
                    salon = 'AULA EXPERIMENTAL TRANSVERSAL' if salon.group(3) == 'AULA EXPERIMENTAL' else salon.group(3)
                    salon = 'AULA ARTES ESCENICAS - DANZA' if salon == 'AULA ARTES ESCENICAS -' and  espacio_Academico.group(1) == "CREACION COREOGRAFICA CONTEMPORANEA PARA LA EDUCACION BASICA" or espacio_Academico.group(1) == "CONCIENCIA CORPORAL, PRE-DANZA Y JUEGO PARA LA ESCUELA" or espacio_Academico.group(1) == "INVESTIGACION Y SISTEMATIZACION DE EXPERIENCIAS EN DIDACTICAS DE LAS ARTES ESCEN" or espacio_Academico.group(1) == "PEDAGOGIA EN LA CREACION COREOGRAFICA CONTEMPORANEA" or espacio_Academico.group(1) == "PEDAGOGIA Y MONTAJE DE LA DANZA TRADICIONAL COLOMBIANA" else salon
                    salon = 'AULA ARTES ESCENICAS - TEATRO' if salon == 'AULA ARTES ESCENICAS -' and  espacio_Academico.group(1) == "DIDACTICAS DE LAS ARTES ESCENICAS" or espacio_Academico.group(1) == "CREACION Y MONTAJE DE COMPARSA EN LA ESCUELA" or espacio_Academico.group(1) == "ESCRITURA Y MONTAJE DE TEATRO EN LA ESCUELA" or espacio_Academico.group(1) == "PEDAGOGIA Y POETICAS EN LA CONSTRUCCION DEL PERSONAJE TEATRAL" or espacio_Academico.group(1) == "ESCRITURA Y MONTAJE DEL TEATRO PARA LA ESCUELA" else salon
                    salon = 'SALA DE TUTORIAS Y PRACTICAS 448' if salon == 'SALA DE TUTORIAS Y' and  espacio_Academico.group(1) == "PRACTICAS DE EDUCACION COMUNITARIA" or espacio_Academico.group(1) == "PROPUESTAS CURRICULARES DEL AREA DE CIENCIAS SOCIALES" or espacio_Academico.group(1) == "DISE?O DE PROYECTOS DE AULA EN CIENCIAS SOCIALES" or espacio_Academico.group(1) == "PROYECTO PEDAGOGICO Y SISTEMATIZACION DE EXPERIENCIAS I" or espacio_Academico.group(1) == "PRACTICA DOCENTE I"  else salon
                    salon = 'SALA DE TUTORIAS Y PRACTICAS 449' if salon == 'SALA DE TUTORIAS Y' and  espacio_Academico.group(1) == "PROYECTO PEDAGOGICO Y SISTEMATIZACION DE EXPERIENCIAS II" or espacio_Academico.group(1) == "PRACTICA FORMATIVA I" or espacio_Academico.group(1) == "PRACTICA FORMATIVA II" or espacio_Academico.group(1) == "SEMINARIO DE PROYECTO DE INVESTIGACION II" or espacio_Academico.group(1) == "PRACTICA FORMATIVA III" or espacio_Academico.group(1) == "PRACTICA FORMATIVA IV"  else salon
                    salon = 'AULA DE TRABAJO GRUPAL 413' if salon == 'AULA DE TRABAJO GRUPAL' and  espacio_Academico.group(1) == "COMPRENSION Y PRODUCCION DE TEXTOS" or espacio_Academico.group(1) == "CULTURA POLITICA, ETICA Y CIUDADANA" or espacio_Academico.group(1) == "ELECTIVA II" or espacio_Academico.group(1) == "MEMORIA SOCIAL Y COLECTIVA" or espacio_Academico.group(1) == "ENFOQUES EPISTEMOLOGICOS Y METODOLOGICOS EN INVESTIGACION EDUCATIVA" or espacio_Academico.group(1) == "PROBLEMAS MUNDIALES Y GLOBALIZACION"  or espacio_Academico.group(1) == "MEDIOS Y NUEVAS TECNOLOGIAS" or espacio_Academico.group(1) == "PROBLEMAS DIDACTICOS DE LAS CIENCIAS SOCIALES EN IBEROAMERICA" or espacio_Academico.group(1) == "PROBLEMAS COLOMBIANOS: SOCIEDAD Y TERRITORIO" or espacio_Academico.group(1) == "ENSE?ANZA DE LAS CIENCIAS SOCIALES EN COLOMBIA" or espacio_Academico.group(1) == "PROYECTO PEDAGOGICO Y SISTEMATIZACION DE EXPERIENCIAS III" or espacio_Academico.group(1) == "GEOPOLITICA SIGLO XX Y XXI" else salon
                    salon = 'AULA DE TRABAJO GRUPAL 454' if salon == 'AULA DE TRABAJO GRUPAL' and  espacio_Academico.group(1) == "CALCULO INTEGRAL" or espacio_Academico.group(1) == "ALGEBRA LINEAL" or espacio_Academico.group(1) == "ECUACIONES DIFERENCIALES" or espacio_Academico.group(1) == "VIBRACIONES Y ONDAS" or espacio_Academico.group(1) == "ESCRITURA Y PRESENTACION DE TRABAJOS CIENTIFICOS" or espacio_Academico.group(1) == "MECANICA TEORICA"  or espacio_Academico.group(1) == "CIENCIA Y ARTE" or espacio_Academico.group(1) == "TOPICOS DE OPTICA FISICA EN MATERIALES" or espacio_Academico.group(1) == "INTRODUCCION A LA FISICA" or espacio_Academico.group(1) == "MATEMATICAS BASICAS" or espacio_Academico.group(1) == "INTRODUCCION A LA DIDACTICA" or espacio_Academico.group(1) == "CONTEXTOS EDUCATIVOS I"  or espacio_Academico.group(1) == "MECANICA CLASICA II" or espacio_Academico.group(1) == "DIDACTICA DE LA FISICA II" or espacio_Academico.group(1) == "PEI - RESOLUCION DE CONFLICTOS" else salon
                    salon = 'AULA DE TRABAJO GRUPAL 526' if salon == 'AULA DE TRABAJO GRUPAL' and  espacio_Academico.group(1) == "NOMENCLATURA QUIMICA" or espacio_Academico.group(1) == "SINTESIS QUIMICA" or espacio_Academico.group(1) == "RADIOQUIMICA" or espacio_Academico.group(1) == "DIDACTICA IV: INVESTIGACION EN EVALUACION Y CURRICULO DE CIENCIAS" or espacio_Academico.group(1) == "TRABAJO DE GRADO I" or espacio_Academico.group(1) == "TRABAJO DE GRADO II"  or espacio_Academico.group(1) == "QUIMICA BASICA I" or espacio_Academico.group(1) == "BIOLOGIA" or espacio_Academico.group(1) == "EDUCACION Y CULTURA" or espacio_Academico.group(1) == "MATEMATICAS II" or espacio_Academico.group(1) == "QUIMICA BASICA II" or espacio_Academico.group(1) == "TEORIAS COGNITIVAS DE APRENDIZAJE"  or espacio_Academico.group(1) == "PPDI- LABORATORIO DE ACERCAMIENTO AL EJERCICIO DE LA PROFESION DOCENTE EN QUIMICA" or espacio_Academico.group(1) == "MODELOS DIDACTICOS EN LA ENSE?ANZA DE LA QUIMICA" or espacio_Academico.group(1) == "ESTADISTICA DESCRIPTIVA"  or espacio_Academico.group(1) == "QUIMICA ANALITICA"  or espacio_Academico.group(1) == "QUIMICA ORGANICA"  or espacio_Academico.group(1) == "PPD V: APLICACION DE LINEAMIENTOS CURRICULARES EN LA ESCUELA"  or espacio_Academico.group(1) == "QUIMICA AMBIENTAL Y SOSTENIBLE"  or espacio_Academico.group(1) == "PPD VI: GESTION DE LA EVALUACION EDUCATIVA"  or espacio_Academico.group(1) == "EVALUACION DE APRENDIZAJE" else salon

                    
                    docente = re.search('\d (MACARENA \- \w|POSTGRADOS|PORVENIR|POR ASIGNAR) (PRACTICAS EXTERNAS|POR ASIGNAR|MONJAS|MACARENA A|LABORATORIOS|BLOQUE \d*|_BLOQUE 3) (TALLER DE GRABADO|TALLER DE ARTES PLASTICAS|SALA DE TUTORIAS Y|SALA DE SISTEMAS|SALA DE INFORMATICA|POR ASIGNAR|LABORATORIO QUIMICA \d|LABORATORIO DE FISICA \d\w|LABORATORIO DE BIOLOGIA 4|LABORATORIO BIOLOGIA \d|LAB\. DIDACT|INSTRUMENTAL N\? 1|EXTERNO [0-9]*|AULA MAGISTRAL [0-9]*|AULA EXPERIMENTAL|AULA DE TRABAJO GRUPAL|AULA DE SISTEMAS [0-9]*|AULA CONVENCIONAL 10A|AULA CONVENCIONAL \d\w|AULA CONVENCIONAL [0-9]*|AULA ARTES VISUALES 703|AULA ARTES MUSICALES [0-9]*|AULA ARTES ESCENICAS \-|AULA [0-9]*|AUDITORIO PRINCIPAL [0-9]*|AUDITORIO PRINCIPAL) (.*)', linea)

                    try:                    
                        docente = docente.group(4)                    
                    except AttributeError:
                        docente = 'POR ASIGNAR'
                    #str(i)+" "+
                    #print(str(i)+" "+sede.group(1))
                    json_constructor.append({"Proyecto_curricular": proyecto_curricular.group(1),
                                             "Grp": grp.group(1),
                                             "Espacio_Academico": espacio_Academico.group(1),
                                             "Cod": cod.group(),
                                             "Dia": dia.group(2),
                                             "Hora": hora.group(),
                                             "Sede": sede.group(1),
                                             "Edificio": edificio.group(2),
                                             "Salon": salon,
                                             "Docente": docente,
                                             "INSCRITOS": inscritos.group(1)})
        i += 1
    pdf.close()    
f = open("prueba_facultad_ciencias_regex.json", 'w+')
f.write(json.dumps(json_constructor, indent=4, sort_keys=True))
f.close()

# %%
s

with pdfplumber.open('horarios_20211_Segunda_Lengua.pdf') as pdf:        
    pagina = pdf.pages[0]
    
    #print(len(pdf.pages))
    for pagina in pdf.pages:
        tuplas =  pagina.extract_words()
        for dato in tuplas: 
            if dato['text'] == 'Sede':
                x0 = dato['x0']
                #print(dato)
            if dato['x0'] == x0 and dato['text'] != 'Sede':
                print(dato['text'])
            #print(dato)
    
    pdf.close()
