# %%
import json
import pandas as pd

# %%
df =  pd.read_json (r'datos_entrada/horarios_20211_Facultad_ciencias_transformado.json')

# %%
df.head(5)
# Out:
#      Cod     Dia                     Docente     Edificio  \
# 0   2006  MARTES  MALDONADO ZAMUDIO BENEDEXA  POR ASIGNAR
# 1   2006  MARTES  MALDONADO ZAMUDIO BENEDEXA  POR ASIGNAR
# 2   2006  MARTES  MALDONADO ZAMUDIO BENEDEXA  POR ASIGNAR
# 3   2006  MARTES  MALDONADO ZAMUDIO BENEDEXA  POR ASIGNAR
# 4  24001   LUNES  VALLEJO SIERRA RUTH HELENA  POR ASIGNAR
#
#                     Espacio_Academico    Grp   Hora  INSCRITOS  \
# 0  PRODUCCION Y COMPRENSION DE TEXTOS  053-1  10-11         30
# 1  PRODUCCION Y COMPRENSION DE TEXTOS  053-1  11-12         30
# 2  PRODUCCION Y COMPRENSION DE TEXTOS  053-2    7-8         30
# 3  PRODUCCION Y COMPRENSION DE TEXTOS  053-2    8-9         30
# 4         FUNDAMENTOS DE ARCHIVISTICA  053-1   9-10         35
#
#                                 Proyecto_curricular        Salon         Sede
# 0  ARCHIVISTICA Y GESTION DE LA INFORMACION DIGITAL  POR ASIGNAR  POR ASIGNAR
# 1  ARCHIVISTICA Y GESTION DE LA INFORMACION DIGITAL  POR ASIGNAR  POR ASIGNAR
# ...

# %%
df[df.Espacio_Academico.str.contains('\?\?')]
# Out:
#        Cod      Dia                      Docente     Edificio  \
# 905   6432  VIERNES     RINCON MU?OZ FLOR ANGELA  POR ASIGNAR
# 906   6432  VIERNES     RINCON MU?OZ FLOR ANGELA  POR ASIGNAR
# 907   6432  VIERNES     RINCON MU?OZ FLOR ANGELA  POR ASIGNAR
# 908   6432  VIERNES     RINCON MU?OZ FLOR ANGELA  POR ASIGNAR
# 3097  4787    LUNES  FORERO CHACON NELSON LIBARD     BLOQUE 3
# 3098  4787    LUNES  FORERO CHACON NELSON LIBARD     BLOQUE 3
# 3099  4787   MARTES  FORERO CHACON NELSON LIBARD     BLOQUE 5
# 3100  4787   MARTES  FORERO CHACON NELSON LIBARD     BLOQUE 5
#
#                                       Espacio_Academico      Grp   Hora  \
# 905   LOS CONFLICTOS FAMILIARES Y SU INCIDENCIA EN E...    188-1    6-7
# 906   LOS CONFLICTOS FAMILIARES Y SU INCIDENCIA EN E...    188-1    7-8
# 907   LOS CONFLICTOS FAMILIARES Y SU INCIDENCIA EN E...    188-2  10-11
# 908   LOS CONFLICTOS FAMILIARES Y SU INCIDENCIA EN E...    188-2  11-12
# ...

# %%
dictionary = {'\?\?':'@@'}
df.replace(dictionary, regex=True, inplace=True)
df[df.Espacio_Academico.str.contains('\@\@')]
# Out:
#        Cod      Dia                      Docente     Edificio  \
# 905   6432  VIERNES     RINCON MU?OZ FLOR ANGELA  POR ASIGNAR
# 906   6432  VIERNES     RINCON MU?OZ FLOR ANGELA  POR ASIGNAR
# 907   6432  VIERNES     RINCON MU?OZ FLOR ANGELA  POR ASIGNAR
# 908   6432  VIERNES     RINCON MU?OZ FLOR ANGELA  POR ASIGNAR
# 3097  4787    LUNES  FORERO CHACON NELSON LIBARD     BLOQUE 3
# 3098  4787    LUNES  FORERO CHACON NELSON LIBARD     BLOQUE 3
# 3099  4787   MARTES  FORERO CHACON NELSON LIBARD     BLOQUE 5
# 3100  4787   MARTES  FORERO CHACON NELSON LIBARD     BLOQUE 5
#
#                                       Espacio_Academico      Grp   Hora  \
# 905   LOS CONFLICTOS FAMILIARES Y SU INCIDENCIA EN E...    188-1    6-7
# 906   LOS CONFLICTOS FAMILIARES Y SU INCIDENCIA EN E...    188-1    7-8
# 907   LOS CONFLICTOS FAMILIARES Y SU INCIDENCIA EN E...    188-2  10-11
# 908   LOS CONFLICTOS FAMILIARES Y SU INCIDENCIA EN E...    188-2  11-12
# ...

# %%
dictionary = {'LOS CONFLICTOS FAMILIARES Y SU INCIDENCIA EN EL @@MBITO EDUCATIVO':'LOS CONFLICTOS FAMILIARES Y SU INCIDENCIA EN EL AMBITO EDUCATIVO', 'INSTRUMENTACI@@N VIRTUAL Y SISTEMAS DE ADQUISICI@@N DE DATOS': 'INSTRUMENTACION VIRTUAL Y SISTEMAS DE ADQUISICION DE DATOS'}
df.replace(dictionary, regex=True, inplace=True)
df[df.Espacio_Academico.str.contains('\@\@')]
# Out:
# Empty DataFrame
# Columns: [Cod, Dia, Docente, Edificio, Espacio_Academico, Grp, Hora, INSCRITOS, Proyecto_curricular, Salon, Sede]
# Index: []

# %%
df[df.Espacio_Academico.str.contains('\?')]
# Out:
#         Cod      Dia                            Docente     Edificio  \
# 451   23931   JUEVES  RODRIGUEZ RODRIGUEZ CESAR AUGUSTO  POR ASIGNAR
# 452   23931   JUEVES  RODRIGUEZ RODRIGUEZ CESAR AUGUSTO  POR ASIGNAR
# 453   23931   JUEVES  RODRIGUEZ RODRIGUEZ CESAR AUGUSTO  POR ASIGNAR
# 454   23931   JUEVES  RODRIGUEZ RODRIGUEZ CESAR AUGUSTO  POR ASIGNAR
# 455   23931  VIERNES  RODRIGUEZ RODRIGUEZ CESAR AUGUSTO  POR ASIGNAR
# ...     ...      ...                                ...          ...
# 5624  21044   MARTES             GARCIA MARTINEZ ALVARO  POR ASIGNAR
# 5625  21044   MARTES             GARCIA MARTINEZ ALVARO  POR ASIGNAR
# 5626  21044   MARTES             GARCIA MARTINEZ ALVARO  POR ASIGNAR
# 5627  21044   JUEVES             GARCIA MARTINEZ ALVARO  POR ASIGNAR
# 5628  21044   JUEVES             GARCIA MARTINEZ ALVARO  POR ASIGNAR
#
#                                       Espacio_Academico    Grp   Hora  \
# ...

# %%
dictionary = {'\?':'Ñ'}
df.replace(dictionary, regex=True, inplace=True)
df[df.Docente.str.contains('Ñ')]
# Out:
#         Cod      Dia                      Docente     Edificio  \
# 62    24012   MARTES  BOLAÑOS FLORIDO LEIDY PAOLA  POR ASIGNAR
# 63    24012   MARTES  BOLAÑOS FLORIDO LEIDY PAOLA  POR ASIGNAR
# 64    24012   MARTES  BOLAÑOS FLORIDO LEIDY PAOLA  POR ASIGNAR
# 89    24020   MARTES  BOLAÑOS FLORIDO LEIDY PAOLA  POR ASIGNAR
# 90    24020   MARTES  BOLAÑOS FLORIDO LEIDY PAOLA  POR ASIGNAR
# ...     ...      ...                          ...          ...
# 5852  19912  VIERNES  BOLAÑOS RIVERA YUDY MARCELA  POR ASIGNAR
# 5853  19912   JUEVES  BOLAÑOS RIVERA YUDY MARCELA  POR ASIGNAR
# 5854  19912   JUEVES  BOLAÑOS RIVERA YUDY MARCELA  POR ASIGNAR
# 5855  19912  VIERNES  BOLAÑOS RIVERA YUDY MARCELA  POR ASIGNAR
# 5856  19912  VIERNES  BOLAÑOS RIVERA YUDY MARCELA  POR ASIGNAR
#
#                            Espacio_Academico    Grp   Hora  INSCRITOS  \
# 62    HISTORIA SOCIAL Y POLITICA DE COLOMBIA  053-1    7-8         27
# ...

# %%
df[df.Espacio_Academico.str.contains('Ñ')]
# Out:
#         Cod      Dia                            Docente     Edificio  \
# 451   23931   JUEVES  RODRIGUEZ RODRIGUEZ CESAR AUGUSTO  POR ASIGNAR
# 452   23931   JUEVES  RODRIGUEZ RODRIGUEZ CESAR AUGUSTO  POR ASIGNAR
# 453   23931   JUEVES  RODRIGUEZ RODRIGUEZ CESAR AUGUSTO  POR ASIGNAR
# 454   23931   JUEVES  RODRIGUEZ RODRIGUEZ CESAR AUGUSTO  POR ASIGNAR
# 455   23931  VIERNES  RODRIGUEZ RODRIGUEZ CESAR AUGUSTO  POR ASIGNAR
# ...     ...      ...                                ...          ...
# 5624  21044   MARTES             GARCIA MARTINEZ ALVARO  POR ASIGNAR
# 5625  21044   MARTES             GARCIA MARTINEZ ALVARO  POR ASIGNAR
# 5626  21044   MARTES             GARCIA MARTINEZ ALVARO  POR ASIGNAR
# 5627  21044   JUEVES             GARCIA MARTINEZ ALVARO  POR ASIGNAR
# 5628  21044   JUEVES             GARCIA MARTINEZ ALVARO  POR ASIGNAR
#
#                                       Espacio_Academico    Grp   Hora  \
# ...

# %%
df.to_json(r'horarios_20211_Facultad_ciencias_limpio.json',orient='records')
