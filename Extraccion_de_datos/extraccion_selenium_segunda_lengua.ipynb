# %%
import time
import os
from selenium.webdriver.common.keys import Keys
from selenium import webdriver 
from selenium.webdriver.chrome.options import Options
import json

# %%
enlace = "https://www.dropbox.com/sh/qe9h0jdh7fgz006/AADWQ5v8_4YRIF61uAbu75oua?dl=0&lst=&preview=horarios_20211_Segunda_Lengua.pdf"
chrome_options=Options()
conf_cliente = {"plugins.plugins_list": [{"enabled": False, "name": "Chrome PDF Viewer"}], "download.default_directory": os.getcwd()}
chrome_options.add_experimental_option("prefs", conf_cliente)
chrome_options.headless = True
chrome_options.add_argument("window-size=1920,1080")
chrome_options.add_argument('user-agent="Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.67 Safari/537.36"')
navegador = webdriver.Chrome(r'./chromedriver', options=chrome_options)
navegador.get(enlace)
time.sleep(3)
item = navegador.find_element_by_class_name('viewer-container')

# %%
item2 = item.find_element_by_class_name("EQJE7qmsBz")
contenedor = item2.find_element_by_tag_name('ol')#lista ordenada html
pagina_0 = contenedor.find_elements_by_tag_name('li')#elemento de lista  html
json_scraper = []

for item in pagina_0:        
    if int(item.get_attribute("data-index")) == 10:
        break                                    
item.location_once_scrolled_into_view

def proceso(indice):        
    paginas = contenedor.find_elements_by_tag_name('li')    
    for pagina in paginas:            
        if int(pagina.get_attribute("data-index")) >= indice+1 or int(pagina.get_attribute("data-index")) == 0:            
            json_scraper.append({"Pagina": int(pagina.get_attribute("data-index")), "nodos":[] }) 
            nodos = pagina.find_elements_by_tag_name('text')                
            for data2 in nodos:
                json_scraper[int(pagina.get_attribute("data-index"))]["nodos"].append({'valor_eje_x': float(data2.get_attribute("x")), 'valor_eje_y': float(data2.get_attribute("y")),'dato': data2.text})
            print("Indice: " + str(indice) + " Pagina: " +pagina.get_attribute("data-index")+" Datos Extraidos: "+ str(len(nodos)))  
    pagina.location_once_scrolled_into_view
    
indice = 0
while indice <= 61:#cantidad de paginas del pdf        
    if indice == 0:                
        proceso(0)
        time.sleep(0.5)    
        indice += 12        
    else:        
        proceso(indice)
        indice += 2
        time.sleep(0.5)    
    indice += 11
    
f = open("horarios_20211_segunda_lengua.json", 'w+')
f.write(json.dumps(json_scraper, indent=4, sort_keys=True))
f.close()
# Out:
# Indice: 0 Pagina: 0 Datos Extraidos: 158
# Indice: 0 Pagina: 1 Datos Extraidos: 176
# Indice: 0 Pagina: 2 Datos Extraidos: 176
# Indice: 0 Pagina: 3 Datos Extraidos: 176
# Indice: 0 Pagina: 4 Datos Extraidos: 176
# Indice: 0 Pagina: 5 Datos Extraidos: 176
# Indice: 0 Pagina: 6 Datos Extraidos: 176
# Indice: 0 Pagina: 7 Datos Extraidos: 176
# Indice: 0 Pagina: 8 Datos Extraidos: 176
# Indice: 0 Pagina: 9 Datos Extraidos: 164
# Indice: 0 Pagina: 10 Datos Extraidos: 122
# Indice: 0 Pagina: 11 Datos Extraidos: 142
# Indice: 0 Pagina: 12 Datos Extraidos: 176
# Indice: 0 Pagina: 13 Datos Extraidos: 176
# Indice: 0 Pagina: 14 Datos Extraidos: 176
# Indice: 0 Pagina: 15 Datos Extraidos: 164
# Indice: 0 Pagina: 16 Datos Extraidos: 176
# Indice: 0 Pagina: 17 Datos Extraidos: 176
# Indice: 0 Pagina: 18 Datos Extraidos: 170
# Indice: 0 Pagina: 19 Datos Extraidos: 172
# Indice: 0 Pagina: 20 Datos Extraidos: 176
# Indice: 0 Pagina: 21 Datos Extraidos: 176
# Indice: 0 Pagina: 22 Datos Extraidos: 176
# Indice: 0 Pagina: 23 Datos Extraidos: 176
# Indice: 23 Pagina: 24 Datos Extraidos: 176
# Indice: 23 Pagina: 25 Datos Extraidos: 144
# Indice: 23 Pagina: 26 Datos Extraidos: 164
# Indice: 23 Pagina: 27 Datos Extraidos: 176
# Indice: 23 Pagina: 28 Datos Extraidos: 176
# Indice: 23 Pagina: 29 Datos Extraidos: 176
# Indice: 23 Pagina: 30 Datos Extraidos: 170
# Indice: 23 Pagina: 31 Datos Extraidos: 172
# Indice: 23 Pagina: 32 Datos Extraidos: 176
# Indice: 23 Pagina: 33 Datos Extraidos: 176
# Indice: 23 Pagina: 34 Datos Extraidos: 176
# Indice: 23 Pagina: 35 Datos Extraidos: 176
# Indice: 23 Pagina: 36 Datos Extraidos: 164
# Indice: 36 Pagina: 37 Datos Extraidos: 128
# Indice: 36 Pagina: 38 Datos Extraidos: 164
# Indice: 36 Pagina: 39 Datos Extraidos: 176
# Indice: 36 Pagina: 40 Datos Extraidos: 176
# Indice: 36 Pagina: 41 Datos Extraidos: 170
# Indice: 36 Pagina: 42 Datos Extraidos: 156
# Indice: 36 Pagina: 43 Datos Extraidos: 178
# Indice: 36 Pagina: 44 Datos Extraidos: 148
# Indice: 36 Pagina: 45 Datos Extraidos: 164
# Indice: 36 Pagina: 46 Datos Extraidos: 154
# Indice: 36 Pagina: 47 Datos Extraidos: 164
# Indice: 36 Pagina: 48 Datos Extraidos: 162
# Indice: 36 Pagina: 49 Datos Extraidos: 176
# Indice: 49 Pagina: 50 Datos Extraidos: 176
# Indice: 49 Pagina: 51 Datos Extraidos: 128
# Indice: 49 Pagina: 52 Datos Extraidos: 152
# Indice: 49 Pagina: 53 Datos Extraidos: 144
# Indice: 49 Pagina: 54 Datos Extraidos: 112
# Indice: 49 Pagina: 55 Datos Extraidos: 168
# Indice: 49 Pagina: 56 Datos Extraidos: 174
# Indice: 49 Pagina: 57 Datos Extraidos: 174
# Indice: 49 Pagina: 58 Datos Extraidos: 204
# Indice: 49 Pagina: 59 Datos Extraidos: 190
# Indice: 49 Pagina: 60 Datos Extraidos: 191
# Indice: 49 Pagina: 61 Datos Extraidos: 143
