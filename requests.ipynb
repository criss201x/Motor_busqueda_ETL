# %%
import requests

# %%
response = requests.get('https://estudiantes.portaloas.udistrital.edu.co/appserv')

# %%
print("Codigo de respuesta: "+str(response.status_code))
print("url: "+response.url)
print("cabecera: "+str(response.headers))
print("contenido: "+ response.text)
# Out:
# Codigo de respuesta: 200
# url: https://estudiantes.portaloas.udistrital.edu.co/appserv/
# cabecera: {'Accept-Ranges': 'bytes', 'Content-Type': 'text/html; charset=UTF-8', 'Date': 'Sat, 15 May 2021 20:57:57 GMT', 'ETag': '"23a7-5bdd128549680"', 'Last-Modified': 'Thu, 18 Mar 2021 15:21:46 GMT', 'Server': 'Apache', 'Content-Length': '9127', 'Connection': 'keep-alive'}
# contenido: <!DOCTYPE html>
# <html lang="es">
#
# <head>
# 	<title>Sistema de Gestión Académica</title>
# 	<meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
# 	<meta http-equiv="X-UA-Compatible" content="IE=edge">
# 	<meta name="viewport" content="width=device-width">
# 	<link rel="shortcut icon" href="index_files/favicon.ico">
# 	<link rel="stylesheet" type="text/css" href="index_files/style.css">
# </head>
#
# <body>
# 	<div id="marcoGeneral">
# 		<div class="seccionAmplia">
# 			<header>
# 				<div id="tabudistrital">
# 					<a href="//www.udistrital.edu.co/">Udistrital</a>
# 				</div>
# ...
