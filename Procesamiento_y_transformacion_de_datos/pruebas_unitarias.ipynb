# %%
import json
import sys,os

# %%
ruta1 = 'datos_entrada/horarios_20211_Facultad_ingenieria.json'

json_transformado = []
#json_scraper.append({"Pagina": int(pagina.get_attribute("data-index")), "nodos":[] }) 
#with open(ruta1, encoding='utf-8') as archivo:
archivo = open(ruta1, encoding='utf-8')    
datos = json.load(archivo)
#print(datos[pg]['nodos'][99])
def concatenador(datos, valor_pivote, pg):
    i = 0
    x = 0
    g = 0
    h = 0
    f = ""
    for dato in datos[pg]['nodos']:
        if i == valor_pivote: 
            x = i
        if x > 0:
            #print(str(i) + " " +datos[pg]['nodos'][i]['dato'] + " " +str(datos[pg]['nodos'][i]['valor_eje_y']))
            if abs(int(datos[pg]['nodos'][valor_pivote]['valor_eje_y'])) == abs(int(datos[pg]['nodos'][i]['valor_eje_y'])) :
                g = i             
                #print(str(g) + " " + datos[pg]['nodos'][i]['dato']) 
            elif datos[pg]['nodos'][i]['dato'].isnumeric() or datos[pg]['nodos'][i]['dato'] == "ESPACIO ACADEMICO" or datos[pg]['nodos'][i]['dato'] == "GRP." or datos[pg]['nodos'][i]['dato'] == "PROYECTO CURRICULAR":
                g = i
            elif i == len(datos[pg]['nodos'])-1:
                h += 1            
                g = i+1
                f += datos[pg]['nodos'][i-1]['dato']+" "    
            else:
                h += 1
                #print(str(g) + " " + datos[pg]['nodos'][i]['dato']) 
                f += datos[pg]['nodos'][i-1]['dato']+" "
        if g > valor_pivote:
            resultado = f+datos[pg]['nodos'][g-1]['dato']
            #print(resultado)
            return resultado, h+1
            #break 
        i += 1   

i = 0
#299
#362 funciona
#364 dañado?
pg = 177
proyecto_curricular = ""
espacio_Academico = ""
dia = ""
hora = ""
sede = ""
edificio = ""
salon = ""
docente = ""
grp = ""
inscritos = 0
cod = 0
json_constructor = []
for dato in datos[pg]['nodos']:    
    #concatenado = concatenador(datos, 96) 
    #print(concatenado)
    #print(dato['dato']+" "+ str(abs(int(dato['valor_eje_y']))))
    if dato['dato'] == 'PROYECTO CURRICULAR':
        proyecto_curricular = datos[pg]['nodos'][i+1]['dato']

    if dato['dato'] == 'GRP.':
        grp = datos[pg]['nodos'][i+1]['dato']

    if dato['dato'] == 'INSCRITOS':
        inscritos = datos[pg]['nodos'][i+1]['dato']

    if datos[pg]['nodos'][i-1]['dato'] != "INSCRITOS":
        if dato['dato'].isnumeric() and abs(int(datos[pg]['nodos'][i]['valor_eje_y']))  == abs(int(datos[pg]['nodos'][i+1]['valor_eje_y'])):
            cod = datos[pg]['nodos'][i]['dato'] 
            #if abs(int(datos[pg]['nodos'][i]['valor_eje_y'])) == abs(int(datos[pg]['nodos'][i+1]['valor_eje_y'])):
                #print(str(i) + " "+datos[pg]['nodos'][i+1]['dato'])
            if abs(int(datos[pg]['nodos'][i+1]['valor_eje_x'])) == abs(int(datos[pg]['nodos'][i+2]['valor_eje_x'])) or abs(abs(int(datos[pg]['nodos'][i+1]['valor_eje_x'])) - abs(int(datos[pg]['nodos'][i+2]['valor_eje_x']))) == 1:
                concatenado, h = concatenador(datos, i+1, pg)                 
                #print(concatenado)
                #print(str(i) + " "+datos[pg]['nodos'][i+h+1]['dato'])
                #print(str(i) + " "+datos[pg]['nodos'][i+h+2]['dato'])
                espacio_Academico = concatenado
                dia = datos[pg]['nodos'][i+h+1]['dato']
                hora = datos[pg]['nodos'][i+h+2]['dato']
            else:                
                h = 1
                #print(str(i) + " "+datos[pg]['nodos'][i+h]['dato'])
                #print(str(i) + " "+datos[pg]['nodos'][i+h+1]['dato'])
                #print(str(i) + " "+datos[pg]['nodos'][i+h+2]['dato'])            
                espacio_Academico = datos[pg]['nodos'][i+h]['dato']
                dia = datos[pg]['nodos'][i+h+1]['dato']
                hora = datos[pg]['nodos'][i+h+2]['dato']

            print(h)
            if abs(int(datos[pg]['nodos'][i]['valor_eje_y'])) != abs(int(datos[pg]['nodos'][i+4+h]['valor_eje_y'])):
                if h > 1:
                    concatenado, h = concatenador(datos, i+5, pg)
                    h += 1
                else:
                    concatenado, h = concatenador(datos, i+4, pg)                    
                #print(concatenado)
                #print(str(i) + " "+datos[pg]['nodos'][i+4]['dato'])
                sede = concatenado
            else:
                if h == 2:
                    h = 2
                    sede = datos[pg]['nodos'][i+5]['dato']
                elif h > 2:
                    h = 3
                    sede = datos[pg]['nodos'][i+6]['dato']                    
                else:                    
                    h = 1          
                    sede = datos[pg]['nodos'][i+4]['dato']
                #print(str(i) + " "+datos[pg]['nodos'][i+4]['dato'])
                
            #print(h)
            if abs(int(datos[pg]['nodos'][i]['valor_eje_y'])) != abs(int(datos[pg]['nodos'][i+4+h+1]['valor_eje_y'])):
                concatenado,q = concatenador(datos, i+4+h, pg)                
                #print(concatenado)                
                #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                edificio = concatenado
                h += 2
            else:
                #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                edificio = datos[pg]['nodos'][i+4+h]['dato']
                h += 1
            #print(h)
            try:            
                if datos[pg]['nodos'][i+4+h+1]['dato'].isnumeric() and abs(int(datos[pg]['nodos'][i+4+h]['valor_eje_x'])) == abs(int(datos[pg]['nodos'][i+4+h+1]['valor_eje_x'])) or abs(abs(int(datos[pg]['nodos'][i+4+h]['valor_eje_x'])) - abs(int(datos[pg]['nodos'][i+4+h+1]['valor_eje_x']))) == 1:
                    #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                    datos[pg]['nodos'][i+4+h+1]['dato'] +="."
                    
                if abs(int(datos[pg]['nodos'][i]['valor_eje_y'])) != abs(int(datos[pg]['nodos'][i+4+h+1]['valor_eje_y'])) and not datos[pg]['nodos'][i+4+h+1]['dato'].isnumeric() and datos[pg]['nodos'][i+4+h+1]['dato'] != "ESPACIO ACADEMICO" and datos[pg]['nodos'][i+4+h+1]['dato'] != "GRP." and datos[pg]['nodos'][i+4+h+1]['dato'] != "PROYECTO CURRICULAR":
                    #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                    concatenado,g = concatenador(datos, i+4+h, pg)
                    salon = concatenado
                    #print(concatenado)
                    if datos[pg]['nodos'][i+4+h+g]['dato'].isnumeric() or datos[pg]['nodos'][i+4+h+g]['dato'] == "GRP." or datos[pg]['nodos'][i+4+h+g]['dato'] == "ESPACIO ACADEMICO" or datos[pg]['nodos'][i+4+h+g]['dato'] == "PROYECTO CURRICULAR":
                        #print("POR ASIGNAR")                      
                        docente = "POR ASIGNAR"
                    else:   
                        docente =  datos[pg]['nodos'][i+4+h+g]['dato']
                        #print(str(i) + " "+datos[pg]['nodos'][i+4+h+g]['dato'])
                else:
                    #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])                    
                    if datos[pg]['nodos'][i+4+h+1]['dato'].isnumeric() or datos[pg]['nodos'][i+4+h+1]['dato'] == "GRP." or datos[pg]['nodos'][i+4+h+1]['dato'] == "ESPACIO ACADEMICO" or datos[pg]['nodos'][i+4+h+1]['dato'] == "PROYECTO CURRICULAR":
                        #print("POR ASIGNAR")                        
                        docente = "POR ASIGNAR"
                    else:
                        docente = datos[pg]['nodos'][i+4+h+1]['dato']
                        #print(str(i) + " "+datos[pg]['nodos'][i+4+h+1]['dato'])
                    salon = datos[pg]['nodos'][i+4+h]['dato']
                    #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                    h = 1
            except IndexError:
                    #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                    #print("POR ASIGNAR 1 ")
                    docente = "POR ASIGNAR"
                    h = 1          
            print(docente)
            json_constructor.append({"Proyecto_curricular": proyecto_curricular,
                                     "Grp": grp,
                                     "Espacio_Academico": espacio_Academico,
                                     "Cod": cod,
                                     "Dia": dia,
                                     "Hora": hora,
                                     "Sede": sede,
                                     "Edificio": edificio,
                                     "Salon": salon,
                                     "Docente": docente,
                                     "INSCRITOS": inscritos})
    i += 1
    #archivo.close()
# Out:
# 3
# LOPEZ SARMIENTO DANILO ALFONSO
# 3
# LOPEZ SARMIENTO DANILO ALFONSO
# 3
# LOPEZ SARMIENTO DANILO ALFONSO
# 3
# LOPEZ SARMIENTO DANILO ALFONSO
# 1
# MOYA CHAVES FRANCISCO DAVID
# 1
# MOYA CHAVES FRANCISCO DAVID
# 1
# MOYA CHAVES FRANCISCO DAVID
# 1
# MOYA CHAVES FRANCISCO DAVID
# 1
# POR ASIGNAR
# 1
# POR ASIGNAR

# %%
i = 0
x = 0
#362
pg = 391
g = 0
h = 0
f = ""
valor_pivote = 150
for dato in datos[pg]['nodos']:    
    print(str(i)+" "+ str(abs(int(datos[pg]['nodos'][i]['valor_eje_x']))) + " " +datos[pg]['nodos'][i]['dato'])
    if i == valor_pivote: 
        x = i
    if x > 0:
        #print(str(i) + " " +datos[pg]['nodos'][i]['dato'] + " " +str(datos[pg]['nodos'][i]['valor_eje_y']))
        if abs(int(datos[pg]['nodos'][valor_pivote]['valor_eje_y'])) == abs(int(datos[pg]['nodos'][i]['valor_eje_y'])):
            g = i
            #print(str(g) + " " + datos[pg]['nodos'][i]['dato']) 
        elif datos[pg]['nodos'][i]['dato'].isnumeric() and datos[pg]['nodos'][g+1]['valor_eje_y'] != datos[pg]['nodos'][i]['valor_eje_y'] or datos[pg]['nodos'][i]['dato'] == "ESPACIO ACADEMICO" or datos[pg]['nodos'][i]['dato'] == "GRP." or datos[pg]['nodos'][i]['dato'] == "PROYECTO CURRICULAR":
            #print(str(i) + " " + datos[pg]['nodos'][g]['dato'])
            #print(str(i) + " " + datos[pg]['nodos'][i]['dato'])
            g = i      
            
        elif i == len(datos[pg]['nodos'])-1:
            h += 1            
            g = i+1
            f += datos[pg]['nodos'][i-1]['dato']+" "
        else:
            h += 1
            #print(str(g) + " " + datos[pg]['nodos'][i]['dato'])
            f += datos[pg]['nodos'][i-1]['dato']+" "
    if g > valor_pivote:
        resultado = f+datos[pg]['nodos'][g-1]['dato']
        print(resultado)
        #return resultado, h+1
        break
    i += 1
# Out:
# 0 31 ESPACIO ACADEMICO
# 1 181 EVALUACION DE APRENDIZAJE
# 2 41 Cod.
# 3 74 Espacio Academico
# 4 301 Dia
# 5 367 Hora
# 6 400 Sede
# 7 471 Edificio
# 8 598 Salon
# 9 726 Docente
# 10 38 21041
# 11 74 EVALUACION DE APRENDIZAJE
# 12 301 MARTES
# 13 370 6-7
# 14 400 MACARENA - B
# 15 471 LABORATORIOS
# 16 598 AULA 106
# 17 725 ARAUJO OVIEDO MARIA LUISA
# 18 38 21041
# 19 74 EVALUACION DE APRENDIZAJE
# 20 301 MARTES
# 21 370 7-8
# 22 400 MACARENA - B
# 23 471 LABORATORIOS
# 24 598 AULA 106
# 25 725 ARAUJO OVIEDO MARIA LUISA
# 26 38 21041
# 27 74 EVALUACION DE APRENDIZAJE
# 28 300 JUEVES
# 29 370 6-7
# 30 400 MACARENA - A
# 31 471 MACARENA A
# 32 598 AULA DE TRABAJO GRUPAL
# 33 598 526
# 34 725 ARAUJO OVIEDO MARIA LUISA
# 35 38 21041
# 36 74 EVALUACION DE APRENDIZAJE
# 37 300 JUEVES
# 38 370 7-8
# 39 400 MACARENA - A
# 40 471 MACARENA A
# 41 598 AULA DE TRABAJO GRUPAL
# 42 598 526
# 43 725 ARAUJO OVIEDO MARIA LUISA
# 44 31 ESPACIO ACADEMICO
# 45 180 TIC EN LA ENSE?ANZA DE LAS CIENCIAS EXPERIMENTALES
# 46 41 Cod.
# 47 74 Espacio Academico
# 48 301 Dia
# 49 367 Hora
# 50 400 Sede
# 51 471 Edificio
# 52 598 Salon
# 53 726 Docente
# 54 38 21044
# 55 73 TIC EN LA ENSE?ANZA DE LAS CIENCIAS
# 56 74 EXPERIMENTALES
# 57 301 MARTES
# 58 370 8-9
# 59 400 POR ASIGNAR
# 60 471 POR ASIGNAR
# 61 598 POR ASIGNAR
# 62 726 GARCIA MARTINEZ ALVARO
# 63 38 21044
# 64 73 TIC EN LA ENSE?ANZA DE LAS CIENCIAS
# 65 74 EXPERIMENTALES
# 66 301 MARTES
# 67 367 9-10
# 68 400 POR ASIGNAR
# 69 471 POR ASIGNAR
# 70 598 POR ASIGNAR
# 71 726 GARCIA MARTINEZ ALVARO
# 72 38 21044
# 73 73 TIC EN LA ENSE?ANZA DE LAS CIENCIAS
# 74 74 EXPERIMENTALES
# 75 301 MARTES
# 76 366 10-11
# 77 400 POR ASIGNAR
# 78 471 POR ASIGNAR
# 79 598 POR ASIGNAR
# 80 726 GARCIA MARTINEZ ALVARO
# 81 38 21044
# 82 73 TIC EN LA ENSE?ANZA DE LAS CIENCIAS
# 83 74 EXPERIMENTALES
# 84 300 JUEVES
# 85 370 8-9
# 86 400 POR ASIGNAR
# 87 471 POR ASIGNAR
# 88 598 POR ASIGNAR
# 89 726 GARCIA MARTINEZ ALVARO
# 90 38 21044
# 91 73 TIC EN LA ENSE?ANZA DE LAS CIENCIAS
# 92 74 EXPERIMENTALES
# 93 300 JUEVES
# 94 367 9-10
# 95 400 POR ASIGNAR
# 96 471 POR ASIGNAR
# 97 598 POR ASIGNAR
# 98 726 GARCIA MARTINEZ ALVARO
# 99 31 ESPACIO ACADEMICO
# 100 181 FUNDAMENTOS DE BIOJURIDICA Y BIOPOLITICA
# 101 41 Cod.
# 102 74 Espacio Academico
# 103 301 Dia
# 104 367 Hora
# 105 400 Sede
# 106 471 Edificio
# 107 598 Salon
# 108 726 Docente
# 109 38 21048
# 110 74 FUNDAMENTOS DE BIOJURIDICA Y BIOPOLITICA
# 111 301 LUNES
# 112 370 8-9
# 113 400 MACARENA - B
# 114 471 LABORATORIOS
# 115 598 AULA 106
# 116 726 PINILLA GONZALEZ JAIRO RICARDO
# 117 38 21048
# 118 74 FUNDAMENTOS DE BIOJURIDICA Y BIOPOLITICA
# 119 301 LUNES
# 120 367 9-10
# 121 400 MACARENA - B
# 122 471 LABORATORIOS
# 123 598 AULA 106
# 124 726 PINILLA GONZALEZ JAIRO RICARDO
# 125 31 ESPACIO ACADEMICO
# 126 181 COMPUESTOS HETEROCICLICOS
# 127 41 Cod.
# 128 74 Espacio Academico
# 129 301 Dia
# 130 367 Hora
# 131 400 Sede
# 132 471 Edificio
# 133 598 Salon
# 134 726 Docente
# 135 38 21051
# 136 74 COMPUESTOS HETEROCICLICOS
# 137 301 LUNES
# 138 366 18-19
# 139 400 MACARENA - B
# 140 471 LABORATORIOS
# 141 598 AULA 106
# 142 726 BRAVO PI?EROS NESTOR FABIAN
# 143 38 21051
# 144 74 COMPUESTOS HETEROCICLICOS
# 145 301 LUNES
# 146 366 19-20
# 147 400 MACARENA - B
# 148 471 LABORATORIOS
# 149 598 AULA 106
# 150 726 BRAVO PI?EROS NESTOR FABIAN
# 151 38 21051
# 152 74 COMPUESTOS HETEROCICLICOS
# 153 301 MARTES
# 154 366 18-19
# 155 400 MACARENA - B
# 156 471 LABORATORIOS
# 157 598 LABORATORIO QUIMICA 1
# 158 726 BRAVO PI?EROS NESTOR FABIAN
# 159 38 21051
# BRAVO PI?EROS NESTOR FABIAN 21051 COMPUESTOS HETEROCICLICOS MARTES 18-19 MACARENA - B LABORATORIOS LABORATORIO QUIMICA 1 BRAVO PI?EROS NESTOR FABIAN

# %%
print(len(datos[pg]['nodos']))

# %%
# Out:
# 181

# %%
x =  abs(int(datos[pg]['nodos'][55]['valor_eje_x'])) - abs(int(datos[pg]['nodos'][56]['valor_eje_x']))
print(x)
# Out:
# -1
