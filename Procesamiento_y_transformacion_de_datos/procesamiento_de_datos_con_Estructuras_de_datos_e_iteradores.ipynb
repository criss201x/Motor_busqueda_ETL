# %%
import json

# %%
ruta1 = 'datos_entrada/horarios_20211_Facultad_artes.json'
ruta2 = 'datos_entrada/horarios_20211_Facultad_tecnologica.json'
ruta3 = 'datos_entrada/horarios_20211_Facultad_ciencias.json'
ruta4 = 'datos_entrada/horarios_20211_Facultad_ingenieria.json'
ruta5 = 'datos_entrada/horarios_20211_Facultad_medio_ambiente.json'
ruta6 = 'datos_entrada/horarios_20211_segunda_lengua.json'
json_transformado = []
#json_scraper.append({"Pagina": int(pagina.get_attribute("data-index")), "nodos":[] }) 
#archivo = open(ruta1, encoding='utf-8')    
archivo = open(ruta1, encoding='utf-8')    
datos = json.load(archivo)
#print(datos[pg]['nodos'][99])
def concatenador(datos, valor_pivote, pg):
    i = 0
    x = 0
    g = 0
    h = 0
    f = ""
    for dato in datos[pg]['nodos']:
        if i == valor_pivote: 
            x = i
        if x > 0:
            #print(str(i) + " " +datos[pg]['nodos'][i]['dato'] + " " +str(datos[pg]['nodos'][i]['valor_eje_y']))
            if abs(int(datos[pg]['nodos'][valor_pivote]['valor_eje_y'])) == abs(int(datos[pg]['nodos'][i]['valor_eje_y'])) :
                g = i             
                #print(str(g) + " " + datos[pg]['nodos'][i]['dato']) 
            elif datos[pg]['nodos'][i]['dato'].isnumeric() or datos[pg]['nodos'][i]['dato'] == "ESPACIO ACADEMICO" or datos[pg]['nodos'][i]['dato'] == "GRP." or datos[pg]['nodos'][i]['dato'] == "PROYECTO CURRICULAR":
                g = i
            elif i == len(datos[pg]['nodos'])-1:
                h += 1            
                g = i+1
                f += datos[pg]['nodos'][i-1]['dato']+" "    
            else:
                h += 1
                #print(str(g) + " " + datos[pg]['nodos'][i]['dato']) 
                f += datos[pg]['nodos'][i-1]['dato']+" "
        if g > valor_pivote:
            resultado = f+datos[pg]['nodos'][g-1]['dato']
            #print(resultado)
            return resultado, h+1
            #break 
        i += 1   


#pg = 1
proyecto_curricular = ""
espacio_Academico = ""
dia = ""
hora = ""
sede = ""
edificio = ""
salon = ""
docente = ""
grp = ""
inscritos = 0
cod = 0
json_constructor = []

for pg in range(len(datos)):
    i = 0
    for dato in datos[pg]['nodos']:    
        #concatenado = concatenador(datos, 96) 
        #print(concatenado)
        #print(dato['dato']+" "+ str(abs(int(dato['valor_eje_y']))))
        if dato['dato'] == 'PROYECTO CURRICULAR':
            proyecto_curricular = datos[pg]['nodos'][i+1]['dato']

        if dato['dato'] == 'GRP.':
            grp = datos[pg]['nodos'][i+1]['dato']

        if dato['dato'] == 'INSCRITOS':
            inscritos = datos[pg]['nodos'][i+1]['dato']

        if datos[pg]['nodos'][i-1]['dato'] != "INSCRITOS":
            if dato['dato'].isnumeric() and abs(int(datos[pg]['nodos'][i]['valor_eje_y']))  == abs(int(datos[pg]['nodos'][i+1]['valor_eje_y'])):
                cod = datos[pg]['nodos'][i]['dato'] 
                #if abs(int(datos[pg]['nodos'][i]['valor_eje_y'])) == abs(int(datos[pg]['nodos'][i+1]['valor_eje_y'])):
                    #print(str(i) + " "+datos[pg]['nodos'][i+1]['dato'])
                if abs(int(datos[pg]['nodos'][i+1]['valor_eje_x'])) == abs(int(datos[pg]['nodos'][i+2]['valor_eje_x'])) or abs(abs(int(datos[pg]['nodos'][i+1]['valor_eje_x'])) - abs(int(datos[pg]['nodos'][i+2]['valor_eje_x']))) == 1:
                    concatenado, h = concatenador(datos, i+1, pg)                 
                    #print(concatenado)
                    #print(str(i) + " "+datos[pg]['nodos'][i+h+1]['dato'])
                    #print(str(i) + " "+datos[pg]['nodos'][i+h+2]['dato'])
                    espacio_Academico = concatenado
                    dia = datos[pg]['nodos'][i+h+1]['dato']
                    hora = datos[pg]['nodos'][i+h+2]['dato']
                else:                
                    h = 1
                    #print(str(i) + " "+datos[pg]['nodos'][i+h]['dato'])
                    #print(str(i) + " "+datos[pg]['nodos'][i+h+1]['dato'])
                    #print(str(i) + " "+datos[pg]['nodos'][i+h+2]['dato'])            
                    espacio_Academico = datos[pg]['nodos'][i+h]['dato']
                    dia = datos[pg]['nodos'][i+h+1]['dato']
                    hora = datos[pg]['nodos'][i+h+2]['dato']

                #print(h)
                if abs(int(datos[pg]['nodos'][i]['valor_eje_y'])) != abs(int(datos[pg]['nodos'][i+4+h]['valor_eje_y'])):
                    if h > 1:
                        concatenado, h = concatenador(datos, i+5, pg)
                        h += 1
                    else:
                        concatenado, h = concatenador(datos, i+4, pg)                    
                    #print(concatenado)
                    #print(str(i) + " "+datos[pg]['nodos'][i+4]['dato'])
                    sede = concatenado
                else:
                    if h == 2:
                        h = 2
                        sede = datos[pg]['nodos'][i+5]['dato']
                    elif h > 2:
                        h = 3
                        sede = datos[pg]['nodos'][i+6]['dato']                    
                    else:                    
                        h = 1          
                        sede = datos[pg]['nodos'][i+4]['dato']
                        #print(str(i) + " "+datos[pg]['nodos'][i+4]['dato'])

                #print(h)
                if abs(int(datos[pg]['nodos'][i]['valor_eje_y'])) != abs(int(datos[pg]['nodos'][i+4+h+1]['valor_eje_y'])):
                    concatenado,q = concatenador(datos, i+4+h, pg)                
                    #print(concatenado)                
                    #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                    edificio = concatenado
                    h += 2
                else:
                    #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                    edificio = datos[pg]['nodos'][i+4+h]['dato']
                    h += 1
                #print(h)
                try:            
                    if datos[pg]['nodos'][i+4+h+1]['dato'].isnumeric() and abs(int(datos[pg]['nodos'][i+4+h]['valor_eje_x'])) == abs(int(datos[pg]['nodos'][i+4+h+1]['valor_eje_x'])) or abs(abs(int(datos[pg]['nodos'][i+4+h]['valor_eje_x'])) - abs(int(datos[pg]['nodos'][i+4+h+1]['valor_eje_x']))) == 1:
                        #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                        datos[pg]['nodos'][i+4+h+1]['dato'] +="."

                    if abs(int(datos[pg]['nodos'][i]['valor_eje_y'])) != abs(int(datos[pg]['nodos'][i+4+h+1]['valor_eje_y'])) and not datos[pg]['nodos'][i+4+h+1]['dato'].isnumeric() and datos[pg]['nodos'][i+4+h+1]['dato'] != "ESPACIO ACADEMICO" and datos[pg]['nodos'][i+4+h+1]['dato'] != "GRP." and datos[pg]['nodos'][i+4+h+1]['dato'] != "PROYECTO CURRICULAR":
                        #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                        concatenado,g = concatenador(datos, i+4+h, pg)
                        salon = concatenado
                        #print(concatenado)
                        if datos[pg]['nodos'][i+4+h+g]['dato'].isnumeric() or datos[pg]['nodos'][i+4+h+g]['dato'] == "GRP." or datos[pg]['nodos'][i+4+h+g]['dato'] == "ESPACIO ACADEMICO" or datos[pg]['nodos'][i+4+h+g]['dato'] == "PROYECTO CURRICULAR":
                            #print("POR ASIGNAR")                      
                            docente = "POR ASIGNAR"
                        else:   
                            docente =  datos[pg]['nodos'][i+4+h+g]['dato']
                            #print(str(i) + " "+datos[pg]['nodos'][i+4+h+g]['dato'])
                    else:
                        #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])                    
                        if datos[pg]['nodos'][i+4+h+1]['dato'].isnumeric() or datos[pg]['nodos'][i+4+h+1]['dato'] == "GRP." or datos[pg]['nodos'][i+4+h+1]['dato'] == "ESPACIO ACADEMICO" or datos[pg]['nodos'][i+4+h+1]['dato'] == "PROYECTO CURRICULAR":
                            #print("POR ASIGNAR")                        
                            docente = "POR ASIGNAR"
                        else:
                            docente = datos[pg]['nodos'][i+4+h+1]['dato']
                            #print(str(i) + " "+datos[pg]['nodos'][i+4+h+1]['dato'])
                        salon = datos[pg]['nodos'][i+4+h]['dato']
                        #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                        h = 1
                except IndexError:
                        #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                        #print("POR ASIGNAR 1 ")
                        docente = "POR ASIGNAR"
                        h = 1          
                #print(sede)
                json_constructor.append({"Proyecto_curricular": proyecto_curricular,
                                         "Grp": grp,
                                         "Espacio_Academico": espacio_Academico,
                                         "Cod": cod,
                                         "Dia": dia,
                                         "Hora": hora,
                                         "Sede": sede,
                                         "Edificio": edificio,
                                         "Salon": salon,
                                         "Docente": docente,
                                         "INSCRITOS": inscritos})
        i += 1
        #archivo.close()

# %%
ruta1 = 'datos_entrada/horarios_20211_Facultad_artes.json'
ruta2 = 'datos_entrada/horarios_20211_Facultad_tecnologica.json'
ruta3 = 'datos_entrada/horarios_20211_Facultad_ciencias.json'
ruta4 = 'datos_entrada/horarios_20211_Facultad_ingenieria.json'
ruta5 = 'datos_entrada/horarios_20211_Facultad_medio_ambiente.json'
ruta6 = 'datos_entrada/horarios_20211_segunda_lengua.json'
json_transformado = []
#json_scraper.append({"Pagina": int(pagina.get_attribute("data-index")), "nodos":[] }) 
#archivo = open(ruta1, encoding='utf-8')    
archivo = open(ruta2, encoding='utf-8')    
datos = json.load(archivo)
#print(datos[pg]['nodos'][99])
def concatenador(datos, valor_pivote, pg):
    i = 0
    x = 0
    g = 0
    h = 0
    f = ""
    for dato in datos[pg]['nodos']:
        if i == valor_pivote: 
            x = i
        if x > 0:
            #print(str(i) + " " +datos[pg]['nodos'][i]['dato'] + " " +str(datos[pg]['nodos'][i]['valor_eje_y']))
            if abs(int(datos[pg]['nodos'][valor_pivote]['valor_eje_y'])) == abs(int(datos[pg]['nodos'][i]['valor_eje_y'])) :
                g = i             
                #print(str(g) + " " + datos[pg]['nodos'][i]['dato']) 
            elif datos[pg]['nodos'][i]['dato'].isnumeric() or datos[pg]['nodos'][i]['dato'] == "ESPACIO ACADEMICO" or datos[pg]['nodos'][i]['dato'] == "GRP." or datos[pg]['nodos'][i]['dato'] == "PROYECTO CURRICULAR":
                g = i
            elif i == len(datos[pg]['nodos'])-1:
                h += 1            
                g = i+1
                f += datos[pg]['nodos'][i-1]['dato']+" "    
            else:
                h += 1
                #print(str(g) + " " + datos[pg]['nodos'][i]['dato']) 
                f += datos[pg]['nodos'][i-1]['dato']+" "
        if g > valor_pivote:
            resultado = f+datos[pg]['nodos'][g-1]['dato']
            #print(resultado)
            return resultado, h+1
            #break 
        i += 1   


#pg = 1
proyecto_curricular = ""
espacio_Academico = ""
dia = ""
hora = ""
sede = ""
edificio = ""
salon = ""
docente = ""
grp = ""
inscritos = 0
cod = 0


for pg in range(len(datos)):
    i = 0
    for dato in datos[pg]['nodos']:    
        #concatenado = concatenador(datos, 96) 
        #print(concatenado)
        #print(dato['dato']+" "+ str(abs(int(dato['valor_eje_y']))))
        if dato['dato'] == 'PROYECTO CURRICULAR':
            proyecto_curricular = datos[pg]['nodos'][i+1]['dato']

        if dato['dato'] == 'GRP.':
            grp = datos[pg]['nodos'][i+1]['dato']

        if dato['dato'] == 'INSCRITOS':
            inscritos = datos[pg]['nodos'][i+1]['dato']

        if datos[pg]['nodos'][i-1]['dato'] != "INSCRITOS":
            if dato['dato'].isnumeric() and abs(int(datos[pg]['nodos'][i]['valor_eje_y']))  == abs(int(datos[pg]['nodos'][i+1]['valor_eje_y'])):
                cod = datos[pg]['nodos'][i]['dato'] 
                #if abs(int(datos[pg]['nodos'][i]['valor_eje_y'])) == abs(int(datos[pg]['nodos'][i+1]['valor_eje_y'])):
                    #print(str(i) + " "+datos[pg]['nodos'][i+1]['dato'])
                if abs(int(datos[pg]['nodos'][i+1]['valor_eje_x'])) == abs(int(datos[pg]['nodos'][i+2]['valor_eje_x'])) or abs(abs(int(datos[pg]['nodos'][i+1]['valor_eje_x'])) - abs(int(datos[pg]['nodos'][i+2]['valor_eje_x']))) == 1:
                    concatenado, h = concatenador(datos, i+1, pg)                 
                    #print(concatenado)
                    #print(str(i) + " "+datos[pg]['nodos'][i+h+1]['dato'])
                    #print(str(i) + " "+datos[pg]['nodos'][i+h+2]['dato'])
                    espacio_Academico = concatenado
                    dia = datos[pg]['nodos'][i+h+1]['dato']
                    hora = datos[pg]['nodos'][i+h+2]['dato']
                else:                
                    h = 1
                    #print(str(i) + " "+datos[pg]['nodos'][i+h]['dato'])
                    #print(str(i) + " "+datos[pg]['nodos'][i+h+1]['dato'])
                    #print(str(i) + " "+datos[pg]['nodos'][i+h+2]['dato'])            
                    espacio_Academico = datos[pg]['nodos'][i+h]['dato']
                    dia = datos[pg]['nodos'][i+h+1]['dato']
                    hora = datos[pg]['nodos'][i+h+2]['dato']

                #print(h)
                if abs(int(datos[pg]['nodos'][i]['valor_eje_y'])) != abs(int(datos[pg]['nodos'][i+4+h]['valor_eje_y'])):
                    if h > 1:
                        concatenado, h = concatenador(datos, i+5, pg)
                        h += 1
                    else:
                        concatenado, h = concatenador(datos, i+4, pg)                    
                    #print(concatenado)
                    #print(str(i) + " "+datos[pg]['nodos'][i+4]['dato'])
                    sede = concatenado
                else:
                    if h == 2:
                        h = 2
                        sede = datos[pg]['nodos'][i+5]['dato']
                    elif h > 2:
                        h = 3
                        sede = datos[pg]['nodos'][i+6]['dato']                    
                    else:                    
                        h = 1          
                        sede = datos[pg]['nodos'][i+4]['dato']
                        #print(str(i) + " "+datos[pg]['nodos'][i+4]['dato'])

                #print(h)
                if abs(int(datos[pg]['nodos'][i]['valor_eje_y'])) != abs(int(datos[pg]['nodos'][i+4+h+1]['valor_eje_y'])):
                    concatenado,q = concatenador(datos, i+4+h, pg)                
                    #print(concatenado)                
                    #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                    edificio = concatenado
                    h += 2
                else:
                    #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                    edificio = datos[pg]['nodos'][i+4+h]['dato']
                    h += 1
                #print(h)
                try:            
                    if datos[pg]['nodos'][i+4+h+1]['dato'].isnumeric() and abs(int(datos[pg]['nodos'][i+4+h]['valor_eje_x'])) == abs(int(datos[pg]['nodos'][i+4+h+1]['valor_eje_x'])) or abs(abs(int(datos[pg]['nodos'][i+4+h]['valor_eje_x'])) - abs(int(datos[pg]['nodos'][i+4+h+1]['valor_eje_x']))) == 1:
                        #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                        datos[pg]['nodos'][i+4+h+1]['dato'] +="."

                    if abs(int(datos[pg]['nodos'][i]['valor_eje_y'])) != abs(int(datos[pg]['nodos'][i+4+h+1]['valor_eje_y'])) and not datos[pg]['nodos'][i+4+h+1]['dato'].isnumeric() and datos[pg]['nodos'][i+4+h+1]['dato'] != "ESPACIO ACADEMICO" and datos[pg]['nodos'][i+4+h+1]['dato'] != "GRP." and datos[pg]['nodos'][i+4+h+1]['dato'] != "PROYECTO CURRICULAR":
                        #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                        concatenado,g = concatenador(datos, i+4+h, pg)
                        salon = concatenado
                        #print(concatenado)
                        if datos[pg]['nodos'][i+4+h+g]['dato'].isnumeric() or datos[pg]['nodos'][i+4+h+g]['dato'] == "GRP." or datos[pg]['nodos'][i+4+h+g]['dato'] == "ESPACIO ACADEMICO" or datos[pg]['nodos'][i+4+h+g]['dato'] == "PROYECTO CURRICULAR":
                            #print("POR ASIGNAR")                      
                            docente = "POR ASIGNAR"
                        else:   
                            docente =  datos[pg]['nodos'][i+4+h+g]['dato']
                            #print(str(i) + " "+datos[pg]['nodos'][i+4+h+g]['dato'])
                    else:
                        #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])                    
                        if datos[pg]['nodos'][i+4+h+1]['dato'].isnumeric() or datos[pg]['nodos'][i+4+h+1]['dato'] == "GRP." or datos[pg]['nodos'][i+4+h+1]['dato'] == "ESPACIO ACADEMICO" or datos[pg]['nodos'][i+4+h+1]['dato'] == "PROYECTO CURRICULAR":
                            #print("POR ASIGNAR")                        
                            docente = "POR ASIGNAR"
                        else:
                            docente = datos[pg]['nodos'][i+4+h+1]['dato']
                            #print(str(i) + " "+datos[pg]['nodos'][i+4+h+1]['dato'])
                        salon = datos[pg]['nodos'][i+4+h]['dato']
                        #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                        h = 1
                except IndexError:
                        #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                        #print("POR ASIGNAR 1 ")
                        docente = "POR ASIGNAR"
                        h = 1          
                #print(sede)
                json_constructor.append({"Proyecto_curricular": proyecto_curricular,
                                         "Grp": grp,
                                         "Espacio_Academico": espacio_Academico,
                                         "Cod": cod,
                                         "Dia": dia,
                                         "Hora": hora,
                                         "Sede": sede,
                                         "Edificio": edificio,
                                         "Salon": salon,
                                         "Docente": docente,
                                         "INSCRITOS": inscritos})
        i += 1
        #archivo.close()

# %%
ruta1 = 'datos_entrada/horarios_20211_Facultad_artes.json'
ruta2 = 'datos_entrada/horarios_20211_Facultad_tecnologica.json'
ruta3 = 'datos_entrada/horarios_20211_Facultad_ciencias.json'
ruta4 = 'datos_entrada/horarios_20211_Facultad_ingenieria.json'
ruta5 = 'datos_entrada/horarios_20211_Facultad_medio_ambiente.json'
ruta6 = 'datos_entrada/horarios_20211_segunda_lengua.json'
json_transformado = []
#json_scraper.append({"Pagina": int(pagina.get_attribute("data-index")), "nodos":[] }) 
#archivo = open(ruta1, encoding='utf-8')    
archivo = open(ruta3, encoding='utf-8')    
datos = json.load(archivo)
#print(datos[pg]['nodos'][99])
def concatenador(datos, valor_pivote, pg):
    i = 0
    x = 0
    g = 0
    h = 0
    f = ""
    for dato in datos[pg]['nodos']:
        if i == valor_pivote: 
            x = i
        if x > 0:
            #print(str(i) + " " +datos[pg]['nodos'][i]['dato'] + " " +str(datos[pg]['nodos'][i]['valor_eje_y']))
            if abs(int(datos[pg]['nodos'][valor_pivote]['valor_eje_y'])) == abs(int(datos[pg]['nodos'][i]['valor_eje_y'])) :
                g = i             
                #print(str(g) + " " + datos[pg]['nodos'][i]['dato']) 
            elif datos[pg]['nodos'][i]['dato'].isnumeric() or datos[pg]['nodos'][i]['dato'] == "ESPACIO ACADEMICO" or datos[pg]['nodos'][i]['dato'] == "GRP." or datos[pg]['nodos'][i]['dato'] == "PROYECTO CURRICULAR":
                g = i
            elif i == len(datos[pg]['nodos'])-1:
                h += 1            
                g = i+1
                f += datos[pg]['nodos'][i-1]['dato']+" "    
            else:
                h += 1
                #print(str(g) + " " + datos[pg]['nodos'][i]['dato']) 
                f += datos[pg]['nodos'][i-1]['dato']+" "
        if g > valor_pivote:
            resultado = f+datos[pg]['nodos'][g-1]['dato']
            #print(resultado)
            return resultado, h+1
            #break 
        i += 1   


#pg = 1
proyecto_curricular = ""
espacio_Academico = ""
dia = ""
hora = ""
sede = ""
edificio = ""
salon = ""
docente = ""
grp = ""
inscritos = 0
cod = 0

for pg in range(len(datos)):
    i = 0
    for dato in datos[pg]['nodos']:    
        #concatenado = concatenador(datos, 96) 
        #print(concatenado)
        #print(dato['dato']+" "+ str(abs(int(dato['valor_eje_y']))))
        if dato['dato'] == 'PROYECTO CURRICULAR':
            proyecto_curricular = datos[pg]['nodos'][i+1]['dato']

        if dato['dato'] == 'GRP.':
            grp = datos[pg]['nodos'][i+1]['dato']

        if dato['dato'] == 'INSCRITOS':
            inscritos = datos[pg]['nodos'][i+1]['dato']

        if datos[pg]['nodos'][i-1]['dato'] != "INSCRITOS":
            if dato['dato'].isnumeric() and abs(int(datos[pg]['nodos'][i]['valor_eje_y']))  == abs(int(datos[pg]['nodos'][i+1]['valor_eje_y'])):
                cod = datos[pg]['nodos'][i]['dato'] 
                #if abs(int(datos[pg]['nodos'][i]['valor_eje_y'])) == abs(int(datos[pg]['nodos'][i+1]['valor_eje_y'])):
                    #print(str(i) + " "+datos[pg]['nodos'][i+1]['dato'])
                if abs(int(datos[pg]['nodos'][i+1]['valor_eje_x'])) == abs(int(datos[pg]['nodos'][i+2]['valor_eje_x'])) or abs(abs(int(datos[pg]['nodos'][i+1]['valor_eje_x'])) - abs(int(datos[pg]['nodos'][i+2]['valor_eje_x']))) == 1:
                    concatenado, h = concatenador(datos, i+1, pg)                 
                    #print(concatenado)
                    #print(str(i) + " "+datos[pg]['nodos'][i+h+1]['dato'])
                    #print(str(i) + " "+datos[pg]['nodos'][i+h+2]['dato'])
                    espacio_Academico = concatenado
                    dia = datos[pg]['nodos'][i+h+1]['dato']
                    hora = datos[pg]['nodos'][i+h+2]['dato']
                else:                
                    h = 1
                    #print(str(i) + " "+datos[pg]['nodos'][i+h]['dato'])
                    #print(str(i) + " "+datos[pg]['nodos'][i+h+1]['dato'])
                    #print(str(i) + " "+datos[pg]['nodos'][i+h+2]['dato'])            
                    espacio_Academico = datos[pg]['nodos'][i+h]['dato']
                    dia = datos[pg]['nodos'][i+h+1]['dato']
                    hora = datos[pg]['nodos'][i+h+2]['dato']

                #print(h)
                if abs(int(datos[pg]['nodos'][i]['valor_eje_y'])) != abs(int(datos[pg]['nodos'][i+4+h]['valor_eje_y'])):
                    if h > 1:
                        concatenado, h = concatenador(datos, i+5, pg)
                        h += 1
                    else:
                        concatenado, h = concatenador(datos, i+4, pg)                    
                    #print(concatenado)
                    #print(str(i) + " "+datos[pg]['nodos'][i+4]['dato'])
                    sede = concatenado
                else:
                    if h == 2:
                        h = 2
                        sede = datos[pg]['nodos'][i+5]['dato']
                    elif h > 2:
                        h = 3
                        sede = datos[pg]['nodos'][i+6]['dato']                    
                    else:                    
                        h = 1          
                        sede = datos[pg]['nodos'][i+4]['dato']
                        #print(str(i) + " "+datos[pg]['nodos'][i+4]['dato'])

                #print(h)
                if abs(int(datos[pg]['nodos'][i]['valor_eje_y'])) != abs(int(datos[pg]['nodos'][i+4+h+1]['valor_eje_y'])):
                    concatenado,q = concatenador(datos, i+4+h, pg)                
                    #print(concatenado)                
                    #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                    edificio = concatenado
                    h += 2
                else:
                    #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                    edificio = datos[pg]['nodos'][i+4+h]['dato']
                    h += 1
                #print(h)
                try:            
                    if datos[pg]['nodos'][i+4+h+1]['dato'].isnumeric() and abs(int(datos[pg]['nodos'][i+4+h]['valor_eje_x'])) == abs(int(datos[pg]['nodos'][i+4+h+1]['valor_eje_x'])) or abs(abs(int(datos[pg]['nodos'][i+4+h]['valor_eje_x'])) - abs(int(datos[pg]['nodos'][i+4+h+1]['valor_eje_x']))) == 1:
                        #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                        datos[pg]['nodos'][i+4+h+1]['dato'] +="."

                    if abs(int(datos[pg]['nodos'][i]['valor_eje_y'])) != abs(int(datos[pg]['nodos'][i+4+h+1]['valor_eje_y'])) and not datos[pg]['nodos'][i+4+h+1]['dato'].isnumeric() and datos[pg]['nodos'][i+4+h+1]['dato'] != "ESPACIO ACADEMICO" and datos[pg]['nodos'][i+4+h+1]['dato'] != "GRP." and datos[pg]['nodos'][i+4+h+1]['dato'] != "PROYECTO CURRICULAR":
                        #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                        concatenado,g = concatenador(datos, i+4+h, pg)
                        salon = concatenado
                        #print(concatenado)
                        if datos[pg]['nodos'][i+4+h+g]['dato'].isnumeric() or datos[pg]['nodos'][i+4+h+g]['dato'] == "GRP." or datos[pg]['nodos'][i+4+h+g]['dato'] == "ESPACIO ACADEMICO" or datos[pg]['nodos'][i+4+h+g]['dato'] == "PROYECTO CURRICULAR":
                            #print("POR ASIGNAR")                      
                            docente = "POR ASIGNAR"
                        else:   
                            docente =  datos[pg]['nodos'][i+4+h+g]['dato']
                            #print(str(i) + " "+datos[pg]['nodos'][i+4+h+g]['dato'])
                    else:
                        #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])                    
                        if datos[pg]['nodos'][i+4+h+1]['dato'].isnumeric() or datos[pg]['nodos'][i+4+h+1]['dato'] == "GRP." or datos[pg]['nodos'][i+4+h+1]['dato'] == "ESPACIO ACADEMICO" or datos[pg]['nodos'][i+4+h+1]['dato'] == "PROYECTO CURRICULAR":
                            #print("POR ASIGNAR")                        
                            docente = "POR ASIGNAR"
                        else:
                            docente = datos[pg]['nodos'][i+4+h+1]['dato']
                            #print(str(i) + " "+datos[pg]['nodos'][i+4+h+1]['dato'])
                        salon = datos[pg]['nodos'][i+4+h]['dato']
                        #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                        h = 1
                except IndexError:
                        #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                        #print("POR ASIGNAR 1 ")
                        docente = "POR ASIGNAR"
                        h = 1          
                #print(sede)
                json_constructor.append({"Proyecto_curricular": proyecto_curricular,
                                         "Grp": grp,
                                         "Espacio_Academico": espacio_Academico,
                                         "Cod": cod,
                                         "Dia": dia,
                                         "Hora": hora,
                                         "Sede": sede,
                                         "Edificio": edificio,
                                         "Salon": salon,
                                         "Docente": docente,
                                         "INSCRITOS": inscritos})
        i += 1
        #archivo.close()

# %%
ruta1 = 'datos_entrada/horarios_20211_Facultad_artes.json'
ruta2 = 'datos_entrada/horarios_20211_Facultad_tecnologica.json'
ruta3 = 'datos_entrada/horarios_20211_Facultad_ciencias.json'
ruta4 = 'datos_entrada/horarios_20211_Facultad_ingenieria.json'
ruta5 = 'datos_entrada/horarios_20211_Facultad_medio_ambiente.json'
ruta6 = 'datos_entrada/horarios_20211_segunda_lengua.json'
json_transformado = []
#json_scraper.append({"Pagina": int(pagina.get_attribute("data-index")), "nodos":[] }) 
#archivo = open(ruta1, encoding='utf-8')    
archivo = open(ruta4, encoding='utf-8')    
datos = json.load(archivo)
#print(datos[pg]['nodos'][99])
def concatenador(datos, valor_pivote, pg):
    i = 0
    x = 0
    g = 0
    h = 0
    f = ""
    for dato in datos[pg]['nodos']:
        if i == valor_pivote: 
            x = i
        if x > 0:
            #print(str(i) + " " +datos[pg]['nodos'][i]['dato'] + " " +str(datos[pg]['nodos'][i]['valor_eje_y']))
            if abs(int(datos[pg]['nodos'][valor_pivote]['valor_eje_y'])) == abs(int(datos[pg]['nodos'][i]['valor_eje_y'])) :
                g = i             
                #print(str(g) + " " + datos[pg]['nodos'][i]['dato']) 
            elif datos[pg]['nodos'][i]['dato'].isnumeric() or datos[pg]['nodos'][i]['dato'] == "ESPACIO ACADEMICO" or datos[pg]['nodos'][i]['dato'] == "GRP." or datos[pg]['nodos'][i]['dato'] == "PROYECTO CURRICULAR":
                g = i
            elif i == len(datos[pg]['nodos'])-1:
                h += 1            
                g = i+1
                f += datos[pg]['nodos'][i-1]['dato']+" "    
            else:
                h += 1
                #print(str(g) + " " + datos[pg]['nodos'][i]['dato']) 
                f += datos[pg]['nodos'][i-1]['dato']+" "
        if g > valor_pivote:
            resultado = f+datos[pg]['nodos'][g-1]['dato']
            #print(resultado)
            return resultado, h+1
            #break 
        i += 1   


#pg = 1
proyecto_curricular = ""
espacio_Academico = ""
dia = ""
hora = ""
sede = ""
edificio = ""
salon = ""
docente = ""
grp = ""
inscritos = 0
cod = 0

for pg in range(len(datos)):
    i = 0
    for dato in datos[pg]['nodos']:    
        #concatenado = concatenador(datos, 96) 
        #print(concatenado)
        #print(dato['dato']+" "+ str(abs(int(dato['valor_eje_y']))))
        if dato['dato'] == 'PROYECTO CURRICULAR':
            proyecto_curricular = datos[pg]['nodos'][i+1]['dato']

        if dato['dato'] == 'GRP.':
            grp = datos[pg]['nodos'][i+1]['dato']

        if dato['dato'] == 'INSCRITOS':
            inscritos = datos[pg]['nodos'][i+1]['dato']

        if datos[pg]['nodos'][i-1]['dato'] != "INSCRITOS":
            if dato['dato'].isnumeric() and abs(int(datos[pg]['nodos'][i]['valor_eje_y']))  == abs(int(datos[pg]['nodos'][i+1]['valor_eje_y'])):
                cod = datos[pg]['nodos'][i]['dato'] 
                #if abs(int(datos[pg]['nodos'][i]['valor_eje_y'])) == abs(int(datos[pg]['nodos'][i+1]['valor_eje_y'])):
                    #print(str(i) + " "+datos[pg]['nodos'][i+1]['dato'])
                if abs(int(datos[pg]['nodos'][i+1]['valor_eje_x'])) == abs(int(datos[pg]['nodos'][i+2]['valor_eje_x'])) or abs(abs(int(datos[pg]['nodos'][i+1]['valor_eje_x'])) - abs(int(datos[pg]['nodos'][i+2]['valor_eje_x']))) == 1:
                    concatenado, h = concatenador(datos, i+1, pg)                 
                    #print(concatenado)
                    #print(str(i) + " "+datos[pg]['nodos'][i+h+1]['dato'])
                    #print(str(i) + " "+datos[pg]['nodos'][i+h+2]['dato'])
                    espacio_Academico = concatenado
                    dia = datos[pg]['nodos'][i+h+1]['dato']
                    hora = datos[pg]['nodos'][i+h+2]['dato']
                else:                
                    h = 1
                    #print(str(i) + " "+datos[pg]['nodos'][i+h]['dato'])
                    #print(str(i) + " "+datos[pg]['nodos'][i+h+1]['dato'])
                    #print(str(i) + " "+datos[pg]['nodos'][i+h+2]['dato'])            
                    espacio_Academico = datos[pg]['nodos'][i+h]['dato']
                    dia = datos[pg]['nodos'][i+h+1]['dato']
                    hora = datos[pg]['nodos'][i+h+2]['dato']

                #print(h)
                if abs(int(datos[pg]['nodos'][i]['valor_eje_y'])) != abs(int(datos[pg]['nodos'][i+4+h]['valor_eje_y'])):
                    if h > 1:
                        concatenado, h = concatenador(datos, i+5, pg)
                        h += 1
                    else:
                        concatenado, h = concatenador(datos, i+4, pg)                    
                    #print(concatenado)
                    #print(str(i) + " "+datos[pg]['nodos'][i+4]['dato'])
                    sede = concatenado
                else:
                    if h == 2:
                        h = 2
                        sede = datos[pg]['nodos'][i+5]['dato']
                    elif h > 2:
                        h = 3
                        sede = datos[pg]['nodos'][i+6]['dato']                    
                    else:                    
                        h = 1          
                        sede = datos[pg]['nodos'][i+4]['dato']
                        #print(str(i) + " "+datos[pg]['nodos'][i+4]['dato'])

                #print(h)
                if abs(int(datos[pg]['nodos'][i]['valor_eje_y'])) != abs(int(datos[pg]['nodos'][i+4+h+1]['valor_eje_y'])):
                    concatenado,q = concatenador(datos, i+4+h, pg)                
                    #print(concatenado)                
                    #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                    edificio = concatenado
                    h += 2
                else:
                    #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                    edificio = datos[pg]['nodos'][i+4+h]['dato']
                    h += 1
                #print(h)
                try:            
                    if datos[pg]['nodos'][i+4+h+1]['dato'].isnumeric() and abs(int(datos[pg]['nodos'][i+4+h]['valor_eje_x'])) == abs(int(datos[pg]['nodos'][i+4+h+1]['valor_eje_x'])) or abs(abs(int(datos[pg]['nodos'][i+4+h]['valor_eje_x'])) - abs(int(datos[pg]['nodos'][i+4+h+1]['valor_eje_x']))) == 1:
                        #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                        datos[pg]['nodos'][i+4+h+1]['dato'] +="."

                    if abs(int(datos[pg]['nodos'][i]['valor_eje_y'])) != abs(int(datos[pg]['nodos'][i+4+h+1]['valor_eje_y'])) and not datos[pg]['nodos'][i+4+h+1]['dato'].isnumeric() and datos[pg]['nodos'][i+4+h+1]['dato'] != "ESPACIO ACADEMICO" and datos[pg]['nodos'][i+4+h+1]['dato'] != "GRP." and datos[pg]['nodos'][i+4+h+1]['dato'] != "PROYECTO CURRICULAR":
                        #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                        concatenado,g = concatenador(datos, i+4+h, pg)
                        salon = concatenado
                        #print(concatenado)
                        if datos[pg]['nodos'][i+4+h+g]['dato'].isnumeric() or datos[pg]['nodos'][i+4+h+g]['dato'] == "GRP." or datos[pg]['nodos'][i+4+h+g]['dato'] == "ESPACIO ACADEMICO" or datos[pg]['nodos'][i+4+h+g]['dato'] == "PROYECTO CURRICULAR":
                            #print("POR ASIGNAR")                      
                            docente = "POR ASIGNAR"
                        else:   
                            docente =  datos[pg]['nodos'][i+4+h+g]['dato']
                            #print(str(i) + " "+datos[pg]['nodos'][i+4+h+g]['dato'])
                    else:
                        #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])                    
                        if datos[pg]['nodos'][i+4+h+1]['dato'].isnumeric() or datos[pg]['nodos'][i+4+h+1]['dato'] == "GRP." or datos[pg]['nodos'][i+4+h+1]['dato'] == "ESPACIO ACADEMICO" or datos[pg]['nodos'][i+4+h+1]['dato'] == "PROYECTO CURRICULAR":
                            #print("POR ASIGNAR")                        
                            docente = "POR ASIGNAR"
                        else:
                            docente = datos[pg]['nodos'][i+4+h+1]['dato']
                            #print(str(i) + " "+datos[pg]['nodos'][i+4+h+1]['dato'])
                        salon = datos[pg]['nodos'][i+4+h]['dato']
                        #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                        h = 1
                except IndexError:
                        #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                        #print("POR ASIGNAR 1 ")
                        docente = "POR ASIGNAR"
                        h = 1          
                #print(sede)
                json_constructor.append({"Proyecto_curricular": proyecto_curricular,
                                         "Grp": grp,
                                         "Espacio_Academico": espacio_Academico,
                                         "Cod": cod,
                                         "Dia": dia,
                                         "Hora": hora,
                                         "Sede": sede,
                                         "Edificio": edificio,
                                         "Salon": salon,
                                         "Docente": docente,
                                         "INSCRITOS": inscritos})
        i += 1
        #archivo.close()

# %%
ruta1 = 'datos_entrada/horarios_20211_Facultad_artes.json'
ruta2 = 'datos_entrada/horarios_20211_Facultad_tecnologica.json'
ruta3 = 'datos_entrada/horarios_20211_Facultad_ciencias.json'
ruta4 = 'datos_entrada/horarios_20211_Facultad_ingenieria.json'
ruta5 = 'datos_entrada/horarios_20211_Facultad_medio_ambiente.json'
ruta6 = 'datos_entrada/horarios_20211_segunda_lengua.json'
json_transformado = []
#json_scraper.append({"Pagina": int(pagina.get_attribute("data-index")), "nodos":[] }) 
#archivo = open(ruta1, encoding='utf-8')    
archivo = open(ruta5, encoding='utf-8')    
datos = json.load(archivo)
#print(datos[pg]['nodos'][99])
def concatenador(datos, valor_pivote, pg):
    i = 0
    x = 0
    g = 0
    h = 0
    f = ""
    for dato in datos[pg]['nodos']:
        if i == valor_pivote: 
            x = i
        if x > 0:
            #print(str(i) + " " +datos[pg]['nodos'][i]['dato'] + " " +str(datos[pg]['nodos'][i]['valor_eje_y']))
            if abs(int(datos[pg]['nodos'][valor_pivote]['valor_eje_y'])) == abs(int(datos[pg]['nodos'][i]['valor_eje_y'])) :
                g = i             
                #print(str(g) + " " + datos[pg]['nodos'][i]['dato']) 
            elif datos[pg]['nodos'][i]['dato'].isnumeric() or datos[pg]['nodos'][i]['dato'] == "ESPACIO ACADEMICO" or datos[pg]['nodos'][i]['dato'] == "GRP." or datos[pg]['nodos'][i]['dato'] == "PROYECTO CURRICULAR":
                g = i
            elif i == len(datos[pg]['nodos'])-1:
                h += 1            
                g = i+1
                f += datos[pg]['nodos'][i-1]['dato']+" "    
            else:
                h += 1
                #print(str(g) + " " + datos[pg]['nodos'][i]['dato']) 
                f += datos[pg]['nodos'][i-1]['dato']+" "
        if g > valor_pivote:
            resultado = f+datos[pg]['nodos'][g-1]['dato']
            #print(resultado)
            return resultado, h+1
            #break 
        i += 1   


#pg = 1
proyecto_curricular = ""
espacio_Academico = ""
dia = ""
hora = ""
sede = ""
edificio = ""
salon = ""
docente = ""
grp = ""
inscritos = 0
cod = 0

for pg in range(len(datos)):
    i = 0
    for dato in datos[pg]['nodos']:    
        #concatenado = concatenador(datos, 96) 
        #print(concatenado)
        #print(dato['dato']+" "+ str(abs(int(dato['valor_eje_y']))))
        if dato['dato'] == 'PROYECTO CURRICULAR':
            proyecto_curricular = datos[pg]['nodos'][i+1]['dato']

        if dato['dato'] == 'GRP.':
            grp = datos[pg]['nodos'][i+1]['dato']

        if dato['dato'] == 'INSCRITOS':
            inscritos = datos[pg]['nodos'][i+1]['dato']

        if datos[pg]['nodos'][i-1]['dato'] != "INSCRITOS":
            if dato['dato'].isnumeric() and abs(int(datos[pg]['nodos'][i]['valor_eje_y']))  == abs(int(datos[pg]['nodos'][i+1]['valor_eje_y'])):
                cod = datos[pg]['nodos'][i]['dato'] 
                #if abs(int(datos[pg]['nodos'][i]['valor_eje_y'])) == abs(int(datos[pg]['nodos'][i+1]['valor_eje_y'])):
                    #print(str(i) + " "+datos[pg]['nodos'][i+1]['dato'])
                if abs(int(datos[pg]['nodos'][i+1]['valor_eje_x'])) == abs(int(datos[pg]['nodos'][i+2]['valor_eje_x'])) or abs(abs(int(datos[pg]['nodos'][i+1]['valor_eje_x'])) - abs(int(datos[pg]['nodos'][i+2]['valor_eje_x']))) == 1:
                    concatenado, h = concatenador(datos, i+1, pg)                 
                    #print(concatenado)
                    #print(str(i) + " "+datos[pg]['nodos'][i+h+1]['dato'])
                    #print(str(i) + " "+datos[pg]['nodos'][i+h+2]['dato'])
                    espacio_Academico = concatenado
                    dia = datos[pg]['nodos'][i+h+1]['dato']
                    hora = datos[pg]['nodos'][i+h+2]['dato']
                else:                
                    h = 1
                    #print(str(i) + " "+datos[pg]['nodos'][i+h]['dato'])
                    #print(str(i) + " "+datos[pg]['nodos'][i+h+1]['dato'])
                    #print(str(i) + " "+datos[pg]['nodos'][i+h+2]['dato'])            
                    espacio_Academico = datos[pg]['nodos'][i+h]['dato']
                    dia = datos[pg]['nodos'][i+h+1]['dato']
                    hora = datos[pg]['nodos'][i+h+2]['dato']

                #print(h)
                if abs(int(datos[pg]['nodos'][i]['valor_eje_y'])) != abs(int(datos[pg]['nodos'][i+4+h]['valor_eje_y'])):
                    if h > 1:
                        concatenado, h = concatenador(datos, i+5, pg)
                        h += 1
                    else:
                        concatenado, h = concatenador(datos, i+4, pg)                    
                    #print(concatenado)
                    #print(str(i) + " "+datos[pg]['nodos'][i+4]['dato'])
                    sede = concatenado
                else:
                    if h == 2:
                        h = 2
                        sede = datos[pg]['nodos'][i+5]['dato']
                    elif h > 2:
                        h = 3
                        sede = datos[pg]['nodos'][i+6]['dato']                    
                    else:                    
                        h = 1          
                        sede = datos[pg]['nodos'][i+4]['dato']
                        #print(str(i) + " "+datos[pg]['nodos'][i+4]['dato'])

                #print(h)
                if abs(int(datos[pg]['nodos'][i]['valor_eje_y'])) != abs(int(datos[pg]['nodos'][i+4+h+1]['valor_eje_y'])):
                    concatenado,q = concatenador(datos, i+4+h, pg)                
                    #print(concatenado)                
                    #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                    edificio = concatenado
                    h += 2
                else:
                    #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                    edificio = datos[pg]['nodos'][i+4+h]['dato']
                    h += 1
                #print(h)
                try:            
                    if datos[pg]['nodos'][i+4+h+1]['dato'].isnumeric() and abs(int(datos[pg]['nodos'][i+4+h]['valor_eje_x'])) == abs(int(datos[pg]['nodos'][i+4+h+1]['valor_eje_x'])) or abs(abs(int(datos[pg]['nodos'][i+4+h]['valor_eje_x'])) - abs(int(datos[pg]['nodos'][i+4+h+1]['valor_eje_x']))) == 1:
                        #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                        datos[pg]['nodos'][i+4+h+1]['dato'] +="."

                    if abs(int(datos[pg]['nodos'][i]['valor_eje_y'])) != abs(int(datos[pg]['nodos'][i+4+h+1]['valor_eje_y'])) and not datos[pg]['nodos'][i+4+h+1]['dato'].isnumeric() and datos[pg]['nodos'][i+4+h+1]['dato'] != "ESPACIO ACADEMICO" and datos[pg]['nodos'][i+4+h+1]['dato'] != "GRP." and datos[pg]['nodos'][i+4+h+1]['dato'] != "PROYECTO CURRICULAR":
                        #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                        concatenado,g = concatenador(datos, i+4+h, pg)
                        salon = concatenado
                        #print(concatenado)
                        if datos[pg]['nodos'][i+4+h+g]['dato'].isnumeric() or datos[pg]['nodos'][i+4+h+g]['dato'] == "GRP." or datos[pg]['nodos'][i+4+h+g]['dato'] == "ESPACIO ACADEMICO" or datos[pg]['nodos'][i+4+h+g]['dato'] == "PROYECTO CURRICULAR":
                            #print("POR ASIGNAR")                      
                            docente = "POR ASIGNAR"
                        else:   
                            docente =  datos[pg]['nodos'][i+4+h+g]['dato']
                            #print(str(i) + " "+datos[pg]['nodos'][i+4+h+g]['dato'])
                    else:
                        #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])                    
                        if datos[pg]['nodos'][i+4+h+1]['dato'].isnumeric() or datos[pg]['nodos'][i+4+h+1]['dato'] == "GRP." or datos[pg]['nodos'][i+4+h+1]['dato'] == "ESPACIO ACADEMICO" or datos[pg]['nodos'][i+4+h+1]['dato'] == "PROYECTO CURRICULAR":
                            #print("POR ASIGNAR")                        
                            docente = "POR ASIGNAR"
                        else:
                            docente = datos[pg]['nodos'][i+4+h+1]['dato']
                            #print(str(i) + " "+datos[pg]['nodos'][i+4+h+1]['dato'])
                        salon = datos[pg]['nodos'][i+4+h]['dato']
                        #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                        h = 1
                except IndexError:
                        #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                        #print("POR ASIGNAR 1 ")
                        docente = "POR ASIGNAR"
                        h = 1          
                #print(sede)
                json_constructor.append({"Proyecto_curricular": proyecto_curricular,
                                         "Grp": grp,
                                         "Espacio_Academico": espacio_Academico,
                                         "Cod": cod,
                                         "Dia": dia,
                                         "Hora": hora,
                                         "Sede": sede,
                                         "Edificio": edificio,
                                         "Salon": salon,
                                         "Docente": docente,
                                         "INSCRITOS": inscritos})
        i += 1
        #archivo.close()

# %%
ruta1 = 'datos_entrada/horarios_20211_Facultad_artes.json'
ruta2 = 'datos_entrada/horarios_20211_Facultad_tecnologica.json'
ruta3 = 'datos_entrada/horarios_20211_Facultad_ciencias.json'
ruta4 = 'datos_entrada/horarios_20211_Facultad_ingenieria.json'
ruta5 = 'datos_entrada/horarios_20211_Facultad_medio_ambiente.json'
ruta6 = 'datos_entrada/horarios_20211_segunda_lengua.json'
json_transformado = []
#json_scraper.append({"Pagina": int(pagina.get_attribute("data-index")), "nodos":[] }) 
#archivo = open(ruta1, encoding='utf-8')    
archivo = open(ruta6, encoding='utf-8')    
datos = json.load(archivo)
#print(datos[pg]['nodos'][99])
def concatenador(datos, valor_pivote, pg):
    i = 0
    x = 0
    g = 0
    h = 0
    f = ""
    for dato in datos[pg]['nodos']:
        if i == valor_pivote: 
            x = i
        if x > 0:
            #print(str(i) + " " +datos[pg]['nodos'][i]['dato'] + " " +str(datos[pg]['nodos'][i]['valor_eje_y']))
            if abs(int(datos[pg]['nodos'][valor_pivote]['valor_eje_y'])) == abs(int(datos[pg]['nodos'][i]['valor_eje_y'])) :
                g = i             
                #print(str(g) + " " + datos[pg]['nodos'][i]['dato']) 
            elif datos[pg]['nodos'][i]['dato'].isnumeric() or datos[pg]['nodos'][i]['dato'] == "ESPACIO ACADEMICO" or datos[pg]['nodos'][i]['dato'] == "GRP." or datos[pg]['nodos'][i]['dato'] == "PROYECTO CURRICULAR":
                g = i
            elif i == len(datos[pg]['nodos'])-1:
                h += 1            
                g = i+1
                f += datos[pg]['nodos'][i-1]['dato']+" "    
            else:
                h += 1
                #print(str(g) + " " + datos[pg]['nodos'][i]['dato']) 
                f += datos[pg]['nodos'][i-1]['dato']+" "
        if g > valor_pivote:
            resultado = f+datos[pg]['nodos'][g-1]['dato']
            #print(resultado)
            return resultado, h+1
            #break 
        i += 1   


#pg = 1
proyecto_curricular = ""
espacio_Academico = ""
dia = ""
hora = ""
sede = ""
edificio = ""
salon = ""
docente = ""
grp = ""
inscritos = 0
cod = 0

for pg in range(len(datos)):
    i = 0
    for dato in datos[pg]['nodos']:    
        #concatenado = concatenador(datos, 96) 
        #print(concatenado)
        #print(dato['dato']+" "+ str(abs(int(dato['valor_eje_y']))))
        if dato['dato'] == 'PROYECTO CURRICULAR':
            proyecto_curricular = datos[pg]['nodos'][i+1]['dato']

        if dato['dato'] == 'GRP.':
            grp = datos[pg]['nodos'][i+1]['dato']

        if dato['dato'] == 'INSCRITOS':
            inscritos = datos[pg]['nodos'][i+1]['dato']

        if datos[pg]['nodos'][i-1]['dato'] != "INSCRITOS":
            if dato['dato'].isnumeric() and abs(int(datos[pg]['nodos'][i]['valor_eje_y']))  == abs(int(datos[pg]['nodos'][i+1]['valor_eje_y'])):
                cod = datos[pg]['nodos'][i]['dato'] 
                #if abs(int(datos[pg]['nodos'][i]['valor_eje_y'])) == abs(int(datos[pg]['nodos'][i+1]['valor_eje_y'])):
                    #print(str(i) + " "+datos[pg]['nodos'][i+1]['dato'])
                if abs(int(datos[pg]['nodos'][i+1]['valor_eje_x'])) == abs(int(datos[pg]['nodos'][i+2]['valor_eje_x'])) or abs(abs(int(datos[pg]['nodos'][i+1]['valor_eje_x'])) - abs(int(datos[pg]['nodos'][i+2]['valor_eje_x']))) == 1:
                    concatenado, h = concatenador(datos, i+1, pg)                 
                    #print(concatenado)
                    #print(str(i) + " "+datos[pg]['nodos'][i+h+1]['dato'])
                    #print(str(i) + " "+datos[pg]['nodos'][i+h+2]['dato'])
                    espacio_Academico = concatenado
                    dia = datos[pg]['nodos'][i+h+1]['dato']
                    hora = datos[pg]['nodos'][i+h+2]['dato']
                else:                
                    h = 1
                    #print(str(i) + " "+datos[pg]['nodos'][i+h]['dato'])
                    #print(str(i) + " "+datos[pg]['nodos'][i+h+1]['dato'])
                    #print(str(i) + " "+datos[pg]['nodos'][i+h+2]['dato'])            
                    espacio_Academico = datos[pg]['nodos'][i+h]['dato']
                    dia = datos[pg]['nodos'][i+h+1]['dato']
                    hora = datos[pg]['nodos'][i+h+2]['dato']

                #print(h)
                if abs(int(datos[pg]['nodos'][i]['valor_eje_y'])) != abs(int(datos[pg]['nodos'][i+4+h]['valor_eje_y'])):
                    if h > 1:
                        concatenado, h = concatenador(datos, i+5, pg)
                        h += 1
                    else:
                        concatenado, h = concatenador(datos, i+4, pg)                    
                    #print(concatenado)
                    #print(str(i) + " "+datos[pg]['nodos'][i+4]['dato'])
                    sede = concatenado
                else:
                    if h == 2:
                        h = 2
                        sede = datos[pg]['nodos'][i+5]['dato']
                    elif h > 2:
                        h = 3
                        sede = datos[pg]['nodos'][i+6]['dato']                    
                    else:                    
                        h = 1          
                        sede = datos[pg]['nodos'][i+4]['dato']
                        #print(str(i) + " "+datos[pg]['nodos'][i+4]['dato'])

                #print(h)
                if abs(int(datos[pg]['nodos'][i]['valor_eje_y'])) != abs(int(datos[pg]['nodos'][i+4+h+1]['valor_eje_y'])):
                    concatenado,q = concatenador(datos, i+4+h, pg)                
                    #print(concatenado)                
                    #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                    edificio = concatenado
                    h += 2
                else:
                    #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                    edificio = datos[pg]['nodos'][i+4+h]['dato']
                    h += 1
                #print(h)
                try:            
                    if datos[pg]['nodos'][i+4+h+1]['dato'].isnumeric() and abs(int(datos[pg]['nodos'][i+4+h]['valor_eje_x'])) == abs(int(datos[pg]['nodos'][i+4+h+1]['valor_eje_x'])) or abs(abs(int(datos[pg]['nodos'][i+4+h]['valor_eje_x'])) - abs(int(datos[pg]['nodos'][i+4+h+1]['valor_eje_x']))) == 1:
                        #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                        datos[pg]['nodos'][i+4+h+1]['dato'] +="."

                    if abs(int(datos[pg]['nodos'][i]['valor_eje_y'])) != abs(int(datos[pg]['nodos'][i+4+h+1]['valor_eje_y'])) and not datos[pg]['nodos'][i+4+h+1]['dato'].isnumeric() and datos[pg]['nodos'][i+4+h+1]['dato'] != "ESPACIO ACADEMICO" and datos[pg]['nodos'][i+4+h+1]['dato'] != "GRP." and datos[pg]['nodos'][i+4+h+1]['dato'] != "PROYECTO CURRICULAR":
                        #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                        concatenado,g = concatenador(datos, i+4+h, pg)
                        salon = concatenado
                        #print(concatenado)
                        if datos[pg]['nodos'][i+4+h+g]['dato'].isnumeric() or datos[pg]['nodos'][i+4+h+g]['dato'] == "GRP." or datos[pg]['nodos'][i+4+h+g]['dato'] == "ESPACIO ACADEMICO" or datos[pg]['nodos'][i+4+h+g]['dato'] == "PROYECTO CURRICULAR":
                            #print("POR ASIGNAR")                      
                            docente = "POR ASIGNAR"
                        else:   
                            docente =  datos[pg]['nodos'][i+4+h+g]['dato']
                            #print(str(i) + " "+datos[pg]['nodos'][i+4+h+g]['dato'])
                    else:
                        #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])                    
                        if datos[pg]['nodos'][i+4+h+1]['dato'].isnumeric() or datos[pg]['nodos'][i+4+h+1]['dato'] == "GRP." or datos[pg]['nodos'][i+4+h+1]['dato'] == "ESPACIO ACADEMICO" or datos[pg]['nodos'][i+4+h+1]['dato'] == "PROYECTO CURRICULAR":
                            #print("POR ASIGNAR")                        
                            docente = "POR ASIGNAR"
                        else:
                            docente = datos[pg]['nodos'][i+4+h+1]['dato']
                            #print(str(i) + " "+datos[pg]['nodos'][i+4+h+1]['dato'])
                        salon = datos[pg]['nodos'][i+4+h]['dato']
                        #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                        h = 1
                except IndexError:
                        #print(str(i) + " "+datos[pg]['nodos'][i+4+h]['dato'])
                        #print("POR ASIGNAR 1 ")
                        docente = "POR ASIGNAR"
                        h = 1          
                #print(sede)
                json_constructor.append({"Proyecto_curricular": proyecto_curricular,
                                         "Grp": grp,
                                         "Espacio_Academico": espacio_Academico,
                                         "Cod": cod,
                                         "Dia": dia,
                                         "Hora": hora,
                                         "Sede": sede,
                                         "Edificio": edificio,
                                         "Salon": salon,
                                         "Docente": docente,
                                         "INSCRITOS": inscritos})
        i += 1
        #archivo.close()

# %%
#f = open("horarios_20211_Facultad_tecnologica_transformado.json", 'w+')
#f = open("horarios_20211_Facultad_artes_transformado.json", 'w+')
#f = open("horarios_20211_Facultad_ingenieria_transformado.json", 'w+')
#f = open("horarios_20211_Facultad_medio_ambiente_transformado.json", 'w+')
#f = open("horarios_20211_segunda_lengua_transformado.json", 'w+')
#f = open("horarios_20211_Facultad_ciencias_transformado.json", 'w+')
f = open("horarios_20211_consolidado_transformado.json", 'w+')
f.write(json.dumps(json_constructor, indent=4, sort_keys=True))
f.close()
