# %%
import json
import pandas as pd

# %%
df =  pd.read_json (r'datos_entrada/horarios_20211_Facultad_medio_ambiente_transformado.json')

# %%
df.head(5)
# Out:
#    Cod      Dia                       Docente   Edificio    Espacio_Academico  \
# 0    1   JUEVES  BUSTOS VELASCO VIVIAN ANDREA  _BLOQUE 2  CALCULO DIFERENCIAL
# 1    1   JUEVES  BUSTOS VELASCO VIVIAN ANDREA  _BLOQUE 2  CALCULO DIFERENCIAL
# 2    1  VIERNES  BUSTOS VELASCO VIVIAN ANDREA  _BLOQUE 2  CALCULO DIFERENCIAL
# 3    1  VIERNES  BUSTOS VELASCO VIVIAN ANDREA  _BLOQUE 2  CALCULO DIFERENCIAL
# 4    1  VIERNES  BUSTOS VELASCO VIVIAN ANDREA  _BLOQUE 2  CALCULO DIFERENCIAL
#
#        Grp  Hora  INSCRITOS       Proyecto_curricular                  Salon  \
# 0  185-501   7-8         36  ADMINISTRACION AMBIENTAL  AULA CONVENCIONAL 316
# 1  185-501   8-9         36  ADMINISTRACION AMBIENTAL  AULA CONVENCIONAL 316
# 2  185-501   7-8         36  ADMINISTRACION AMBIENTAL  AULA CONVENCIONAL 203
# 3  185-501   8-9         36  ADMINISTRACION AMBIENTAL  AULA CONVENCIONAL 203
# 4  185-501  9-10         36  ADMINISTRACION AMBIENTAL  AULA CONVENCIONAL 203
#
#        Sede
# 0  PORVENIR
# ...

# %%
df[df.Espacio_Academico.str.contains('\?\?')]
# Out:
#        Cod        Dia                   Docente     Edificio  \
# 188   2412      LUNES               POR ASIGNAR    _BLOQUE 2
# 189   2412      LUNES               POR ASIGNAR    _BLOQUE 2
# 190   2412     MARTES               POR ASIGNAR    _BLOQUE 2
# 191   2412     MARTES               POR ASIGNAR    _BLOQUE 2
# 192   2412      LUNES               POR ASIGNAR    _BLOQUE 2
# 193   2412      LUNES               POR ASIGNAR    _BLOQUE 2
# 194   2412     MARTES               POR ASIGNAR    _BLOQUE 2
# 195   2412     MARTES               POR ASIGNAR    _BLOQUE 2
# 306   2429  MIERCOLES     PAZOS ALVAREZ ALFONSO  POR ASIGNAR
# 307   2429  MIERCOLES     PAZOS ALVAREZ ALFONSO  POR ASIGNAR
# 308   2429  MIERCOLES     PAZOS ALVAREZ ALFONSO  POR ASIGNAR
# 309   2429  MIERCOLES     PAZOS ALVAREZ ALFONSO  POR ASIGNAR
# 310   2429     JUEVES     PAZOS ALVAREZ ALFONSO  POR ASIGNAR
# 311   2429     JUEVES     PAZOS ALVAREZ ALFONSO  POR ASIGNAR
# ...

# %%
dictionary = {'\?\?':'@@'}
df.replace(dictionary, regex=True, inplace=True)
df[df.Espacio_Academico.str.contains('\@\@')]
# Out:
#        Cod        Dia                   Docente     Edificio  \
# 188   2412      LUNES               POR ASIGNAR    _BLOQUE 2
# 189   2412      LUNES               POR ASIGNAR    _BLOQUE 2
# 190   2412     MARTES               POR ASIGNAR    _BLOQUE 2
# 191   2412     MARTES               POR ASIGNAR    _BLOQUE 2
# 192   2412      LUNES               POR ASIGNAR    _BLOQUE 2
# 193   2412      LUNES               POR ASIGNAR    _BLOQUE 2
# 194   2412     MARTES               POR ASIGNAR    _BLOQUE 2
# 195   2412     MARTES               POR ASIGNAR    _BLOQUE 2
# 306   2429  MIERCOLES     PAZOS ALVAREZ ALFONSO  POR ASIGNAR
# 307   2429  MIERCOLES     PAZOS ALVAREZ ALFONSO  POR ASIGNAR
# 308   2429  MIERCOLES     PAZOS ALVAREZ ALFONSO  POR ASIGNAR
# 309   2429  MIERCOLES     PAZOS ALVAREZ ALFONSO  POR ASIGNAR
# 310   2429     JUEVES     PAZOS ALVAREZ ALFONSO  POR ASIGNAR
# 311   2429     JUEVES     PAZOS ALVAREZ ALFONSO  POR ASIGNAR
# ...

# %%
dictionary = {'ADMINISTRACI@@N FINANCIERA':'ADMINISTRACION FINANCIERA', 'FACTORES DE RIESGO AMBIENTAL EN SALUD P@@BLICA': 'FACTORES DE RIESGO AMBIENTAL EN SALUD PUBLICA', 'GESTI@@N AMBIENTAL I': 'GESTION AMBIENTAL I'}
df.replace(dictionary, regex=True, inplace=True)
df[df.Espacio_Academico.str.contains('\@\@')]
# Out:
# Empty DataFrame
# Columns: [Cod, Dia, Docente, Edificio, Espacio_Academico, Grp, Hora, INSCRITOS, Proyecto_curricular, Salon, Sede]
# Index: []

# %%
df[df.Espacio_Academico.str.contains('\?')]
# Out:
#         Cod        Dia                               Docente  \
# 1442   2718     MARTES          BERNAL SUAREZ NESTOR RICARDO
# 1443   2718     MARTES          BERNAL SUAREZ NESTOR RICARDO
# 1444   2718     JUEVES          BERNAL SUAREZ NESTOR RICARDO
# 1445   2718     JUEVES          BERNAL SUAREZ NESTOR RICARDO
# 1446   2718      LUNES          BERNAL SUAREZ NESTOR RICARDO
# 1447   2718      LUNES          BERNAL SUAREZ NESTOR RICARDO
# 1448   2718     MARTES          BERNAL SUAREZ NESTOR RICARDO
# 1449   2718     MARTES          BERNAL SUAREZ NESTOR RICARDO
# 1796  16404     SABADO            CARDENAS ROMERO JOHN FREDY
# 1797  16404     SABADO            CARDENAS ROMERO JOHN FREDY
# 1798  16404     SABADO            CARDENAS ROMERO JOHN FREDY
# 1799  16404     SABADO            CARDENAS ROMERO JOHN FREDY
# 2090   2140     MARTES         CARDONA LONDO?O CLAUDIA MARIA
# 2091   2140     MARTES         CARDONA LONDO?O CLAUDIA MARIA
# ...

# %%
dictionary = {'\?':'Ñ'}
df.replace(dictionary, regex=True, inplace=True)
df[df.Docente.str.contains('Ñ')]
# Out:
#        Cod        Dia                         Docente   Edificio  \
# 116   2112    VIERNES        CEDEÑO MEDINA ELSY ROCIO  _BLOQUE 2
# 117   2112    VIERNES        CEDEÑO MEDINA ELSY ROCIO  _BLOQUE 2
# 118   2112    VIERNES        CEDEÑO MEDINA ELSY ROCIO  _BLOQUE 1
# 119   2112    VIERNES        CEDEÑO MEDINA ELSY ROCIO  _BLOQUE 1
# 208   2415     JUEVES        ZUÑIGA VARGAS PIER PAOLO  _BLOQUE 2
# ...    ...        ...                             ...        ...
# 4037  2509     JUEVES  PEÑARANDA GALVIS VIDAL FERNAND  _BLOQUE 2
# 4054  2517  MIERCOLES   ACOSTA PEÑALOZA GLORIA STELLA  _BLOQUE 2
# 4055  2517  MIERCOLES   ACOSTA PEÑALOZA GLORIA STELLA  _BLOQUE 2
# 4056  2517  MIERCOLES   ACOSTA PEÑALOZA GLORIA STELLA  _BLOQUE 1
# 4057  2517  MIERCOLES   ACOSTA PEÑALOZA GLORIA STELLA  _BLOQUE 1
#
#            Espacio_Academico      Grp   Hora  INSCRITOS  \
# 116   FUNDAMENTOS DE QUIMICA  185-505    7-8         17
# 117   FUNDAMENTOS DE QUIMICA  185-505    8-9         17
# ...

# %%
df[df.Espacio_Academico.str.contains('Ñ')]
# Out:
#         Cod        Dia                               Docente  \
# 1442   2718     MARTES          BERNAL SUAREZ NESTOR RICARDO
# 1443   2718     MARTES          BERNAL SUAREZ NESTOR RICARDO
# 1444   2718     JUEVES          BERNAL SUAREZ NESTOR RICARDO
# 1445   2718     JUEVES          BERNAL SUAREZ NESTOR RICARDO
# 1446   2718      LUNES          BERNAL SUAREZ NESTOR RICARDO
# 1447   2718      LUNES          BERNAL SUAREZ NESTOR RICARDO
# 1448   2718     MARTES          BERNAL SUAREZ NESTOR RICARDO
# 1449   2718     MARTES          BERNAL SUAREZ NESTOR RICARDO
# 1796  16404     SABADO            CARDENAS ROMERO JOHN FREDY
# 1797  16404     SABADO            CARDENAS ROMERO JOHN FREDY
# 1798  16404     SABADO            CARDENAS ROMERO JOHN FREDY
# 1799  16404     SABADO            CARDENAS ROMERO JOHN FREDY
# 2090   2140     MARTES         CARDONA LONDOÑO CLAUDIA MARIA
# 2091   2140     MARTES         CARDONA LONDOÑO CLAUDIA MARIA
# ...

# %%
df.to_json(r'horarios_20211_Facultad_medio_ambiente_limpio.json',orient='records')
